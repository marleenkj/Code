# %%
from loguru import logger
from datetime import timedelta
import pandas as pd
import json
import requests
import numpy as np

import plotly.express as px
import datetime as dt

import math
import time

import haversine

# %reload_ext autoreload
# %autoreload 2

import plotly.graph_objects as go

import sys
sys.path.append('..')
from src.co2_modells import co2_modell, co2_modell_direct
from src.data_matrix import create_dict_points, create_df_distance_matrix
from src.data_for_tool import data_for_tool, create_table_daily_mean, create_table_total
from src.data_for_tool import create_lists_days_weeks_months, create_list_days_month, remove_nan_distance_matrix

# %% [markdown]
# # Data Import

# %%
# Import data
project_path = 'results'
dataset_name = 'df_limited'
df = pd.read_csv(f'{project_path}/{dataset_name}.csv', parse_dates=['Delivery date'])
dataset_name = 'df_distance_matrix'
df_distance_matrix = pd.read_csv(f'{project_path}/{dataset_name}.csv', index_col = 0)

# Import dict terminals
f = open("../data/external/intermodal_terminals/dict_terminals.json")
dict_terminals = json.load(f)

# Import dict points
f = open("../data/processed/dict_points.json")
dict_points = json.load(f)

#df_dc2, df_dc3, df_distance_matrix, dict_terminals, df_terminal = data_for_tool()
list_days, list_mondays, list_bi_daily, list_months = create_lists_days_weeks_months(2022)
list_mondays.append(dt.date(2023, 1, 2))

df_dc1 = df[df["Shipper name"]=="DC1"]
df_dc2 = df[df["Shipper name"]=="DC2"]

len(df["Receiver name"].unique())
# Out:
# 787

# %%
remove_nan_distance_matrix(df, df_distance_matrix)
# Out:
# []
# (           DC1       DC2      C129      C122      C133      C109      C138  \
#  DC1        0.0  583763.2   86015.7  463258.7  615313.4   86445.3  561141.1
#  DC2   581011.6       0.0  541660.6  440804.3  462825.1  508467.9   24726.3
#  C129   85468.8  550743.5       0.0  478484.6  608632.8  103209.2  528121.4
#  C122  444948.7  442362.8  478236.8       0.0  159067.4  362540.1  419740.8
#  C133  615272.6  465374.2  607492.0  158892.4       0.0  532864.0  454953.8
#  ...        ...       ...       ...       ...       ...       ...       ...
#  T6    564288.1   22383.7  524937.3  424080.9  463656.3  491744.5   11227.5
#  T7    590887.8  501278.9  583107.2  171814.4   34545.8  508479.2  490858.5
#  T8    896265.7  485482.1  819532.6  878154.2  930430.5  878857.9  472843.1
#  T9    284953.8  700403.8  294629.1  406047.5  558102.2  200615.9  677781.8
#  T10   401887.3  216263.3  362536.4  228316.1  303256.5  329343.7  193641.2
#
#            C140      C151        C38  ...        T1        T2         T3  \
#  DC1   622413.0   15570.1   868557.4  ...  776291.8  627281.3   814151.5
#  DC2    70583.1  574772.5   687975.4  ...  224461.9  581596.6   768466.8
#  C129  550295.8   67738.4   781784.8  ...  743272.1  540508.6   727378.9
#  C122  481012.6  447525.5  1046233.6  ...  634891.5  907443.2  1094313.5
#  C133  528970.3  617849.3  1096740.8  ...  682849.1  936422.4  1123292.8
#  ...        ...       ...        ...  ...       ...       ...        ...
#  T6     69162.7  558049.1   686555.1  ...  223041.6  565397.4   752267.6
#  T7    564875.0  593464.5  1132645.4  ...  718753.8  972327.1  1159197.4
#  T8    434167.2  878535.4   379534.1  ...  263112.0  462570.4   515800.5
#  T9    739053.6  287530.5  1021577.6  ...  892932.4  780301.5   967171.8
#  T10   254913.1  395648.3   820134.1  ...  408791.9  659815.8   846686.1
#
#              T4        T5        T6        T7         T8         T9       T10
#  DC1   106307.4  402176.8  561801.8  590244.7   896050.0   288705.3  403856.5
#  DC2   503483.1  764752.0   24572.0  498817.3   467986.4   698146.7  216203.6
#  C129  109199.1  338205.2  528782.1  583564.0   818563.3   294435.1  370836.8
#  C122  341561.8  812354.8  420401.5  172619.8   878416.0   385412.5  228604.4
#  C133  511885.7  941609.9  464835.3   33493.4   926373.6   555736.3  303392.9
#  ...        ...       ...       ...       ...        ...        ...       ...
#  T6    486759.6  748552.8       0.0  499648.6   466566.1   681423.3  199480.1
#  T7    487500.9  917225.1  500740.0       0.0   962278.3   531351.5  339297.5
#  T8    876103.5  869808.1  467569.1  966422.8        0.0  1061339.5  653553.5
#  T9    187513.7  628747.0  678442.5  533033.5  1061576.2        0.0  486645.4
#  T10   324358.8  691632.4  194301.9  339248.8   652316.5   485658.5       0.0
#
#  [799 rows x 799 columns],
#  [])

# %%
len(df["Receiver name"].unique())
# Out:
# 787

# %%
truck_capacity = 13000

# %% [markdown]
# > Irgendwie noch den Auslastungsgrad mit einbeziehen

# %%
def get_results_volume_variation(truck_capacity = truck_capacity, mode = "combined", algorithm = "base"):
    # daily
    t = time.process_time()
    df_results = pd.DataFrame(columns = ["date from", "date to", "co2 road", "distance road", "routes road", "processing time road","co2 railroad", "distance railroad", "terminal allocation", "routes railroad", "processing time railroad"])
    for volume in [1,5,10]:
        for i in range(1,len(list_days[:8])):
            try: 
                dict_results, df_results_details = co2_modell(
                df_dc1, df_distance_matrix, dict_terminals, list_days[i-1], list_days[i], 
                volume = volume, mode = mode, truck_capacity = truck_capacity)
                dict_results["volume"] = volume
                df_results = df_results.append(dict_results, ignore_index=True)
            except:
                pass
    return df_results

# %%
def get_results_one_month(df, month, volume, truck_capacity = truck_capacity, mode = "combined", algorithm = "base"):
    list_days = create_list_days_month(2022, month)
    # daily
    t = time.process_time()
    df_results = pd.DataFrame(columns = ["date from", "date to", "co2 road", "distance road", "routes road", "processing time road","co2 railroad", "distance railroad", "terminal allocation", "routes railroad", "processing time railroad"])
    for i in range(1,len(list_days)):
        try: 
            dict_results, df_results_details = co2_modell(
            df, df_distance_matrix, dict_terminals, list_days[i-1], list_days[i], 
            volume = volume, mode = mode, truck_capacity = truck_capacity)
            dict_results["volume"] = volume
            df_results = df_results.append(dict_results, ignore_index=True)
        except:
            pass
    df_results.to_csv(f"results/results_daily_{mode}_{algorithm}_0{month}_v{volume}.csv", index = False)
    return df_results

# %%
df_results = pd.DataFrame(columns = ["date from", "date to", "co2 road", "distance road", "routes road", "processing time road","co2 railroad", "distance railroad", "terminal allocation", "routes railroad", "processing time railroad", "volume"])

# %%
def get_results(df, list_days, planning_horizon, volume, truck_capacity = truck_capacity, mode = "combined", algorithm = "base"):
    t = time.process_time()
    file_path = f"results/results_{planning_horizon}_v{volume}_{mode}_{algorithm}.csv"
    df_results = pd.DataFrame(columns = ["date from", "date to", "co2 road", "distance road", "routes road", "processing time road","co2 railroad", "distance railroad", "terminal allocation", "routes railroad", "processing time railroad"])
    for i in range(0,len(list_days)-1):
        logger.info(f"From {list_days[i]} to {list_days[i+1]}")
        try: 
            dict_results, df_results_details = co2_modell(
                df, df_distance_matrix, dict_terminals, list_days[i], list_days[i+1], 
                volume = volume, mode = mode, truck_capacity = truck_capacity, nb_trucks = 40)
        except:
            try:
                dict_results, df_results_details = co2_modell(
                    df, df_distance_matrix, dict_terminals, list_days[i], list_days[i+1], 
                    volume = volume, mode = mode, truck_capacity = truck_capacity, nb_trucks = 60)
            except:
                try:
                    dict_results, df_results_details = co2_modell(
                        df, df_distance_matrix, dict_terminals, list_days[i], list_days[i+1], 
                        volume = volume, mode = mode, truck_capacity = truck_capacity, nb_trucks = 80)
                except:
                    logger.info("No results")
        dict_results["volume"] = volume
        df_results = df_results.append(dict_results, ignore_index=True)
        df_results.to_csv(f"results/results_{planning_horizon}_v{volume}_{mode}_{algorithm}.csv", index = False)
    return df_results

# %%
df_results.to_csv(f"results/results_{planning_horizon}_v{volume}_{mode}_{algorithm}.csv", index = False)

# %%
mode = "combined"
algorithm = "base"
volume = 10
month = "01"
df_results = pd.read_csv(f"results/results_daily_{mode}_{algorithm}_{month}_v{volume}.csv")
for month in ["02","03","04","05","06","07","08","09","10","11","12"]:
    df_results_month = pd.read_csv(f"results/results_daily_{mode}_{algorithm}_{month}_v{volume}.csv")
    df_results = pd.concat([df_results,df_results_month])

# %%
pip install xlsxwriter
# Out:
# Collecting xlsxwriterNote: you may need to restart the kernel to use updated packages.
#
#   Downloading XlsxWriter-3.1.2-py3-none-any.whl (153 kB)
#      -------------------------------------- 153.0/153.0 kB 1.8 MB/s eta 0:00:00
# Installing collected packages: xlsxwriter
# Successfully installed xlsxwriter-3.1.2

# %%
import xlsxwriter
mode = "combined"
algorithm = "base"
dict_index_names = {0: "GHG road", 1: "GHG rail", 2:"Difference absolut", 3: "Difference relative"}
writer = pd.ExcelWriter(f'results/results_{mode}_{algorithm}.xlsx', engine='xlsxwriter')
for volume in [1, 5, 10]:
    df_results_daily = pd.read_csv(f"results/results_daily_{mode}_{algorithm}_v{volume}.csv")
    df_results_bidaily = pd.read_csv(f"results/results_bidaily_{mode}_{algorithm}_v{volume}.csv")
    df_results_weekly = pd.read_csv(f"results/results_weekly_{mode}_{algorithm}_v{volume}.csv")
    df_results_daily_mean = pd.concat([
        create_table_daily_mean(df_results_daily, "daily planning"),
        create_table_daily_mean(df_results_bidaily, "bi-daily planning"),
        create_table_daily_mean(df_results_weekly, "weekly planning")], axis = 1)
    df_results_daily_mean = df_results_daily_mean.rename(dict_index_names)
    df_results_total = pd.concat([
        create_table_total(df_results_daily, "daily planning"),
        create_table_total(df_results_bidaily, "bi-daily planning"),
        create_table_total(df_results_weekly, "weekly planning")], axis = 1)
    df_results_total = df_results_total.rename(dict_index_names)
    
    # Write each dataframe to a different worksheet.
    df_results_daily_mean.to_excel(writer, sheet_name=f'Daily mean v{volume}')
    df_results_total.to_excel(writer, sheet_name=f'Total v{volume}')
writer.close()
# Out:
# daily planning :  6.7786604064524685
# daily planning :  7.824410548657537
# bi-daily planning :  4.928610573425986
# bi-daily planning :  5.4191116280077996
# weekly planning :  2.253787153128018
# weekly planning :  2.203569577754598
# daily planning :  8.213949623133754
# daily planning :  8.306017353857635
# bi-daily planning :  6.53389821149667
# bi-daily planning :  5.907647991897648
# weekly planning :  4.0892448521044535
# weekly planning :  2.6960362653235252
# daily planning :  9.961960045446707
# daily planning :  8.78944910792969
# bi-daily planning :  7.962918428083938
# bi-daily planning :  6.442686903995213
# weekly planning :  6.710892037942834
# weekly planning :  3.6024471046427626

# %%
df_results_daily_mean.rename({0: "GHG road", 1: "GHG rail", 2:"Difference absolut", 3: "Difference relative"})
# Out:
#                      daily planning  bi-daily planning  weekly planning
# GHG road                6778.660406        4928.610573      2253.787153
# GHG rail                7824.410549        5419.111628      2203.569578
# Difference absolut     -1045.750142        -490.501055        50.217575
# Difference relative      -15.427091          -9.952116         2.228142

# %%
df_results_daily_mean = pd.concat([
    create_table_daily_mean(df_results_daily, "daily planning"),
    create_table_daily_mean(df_results_bidaily, "bi-daily planning"),
    create_table_daily_mean(df_results_weekly, "weekly planning")], axis = 1)
df_results_daily_mean

# %% [markdown]
# # Application of Decision Support Tool

# %% [markdown]
# 1. Base scenario: Rail mandatory
# 2. Scenario: Road allowed
# 3. Scenario: Relaxation 150/20
# 4. Scenario: Multi-modal, Combining the two DC's

# %%
from src.plots import graph_solution, graph_road, graph_solution_with_radius
from src.create_solution import create_solution, create_solution_150_20

# %%
def evaluate_solution(df, date_from, date_to, dict_terminals, list_terminals, volume, truck_capacity = truck_capacity):
    df = df[(df["Delivery date"]>=pd.to_datetime(date_from))&(df["Delivery date"]<=pd.to_datetime(date_to))]
    dict_points = create_dict_points(df, "Shipper name", "Shipper latitude", "Shipper longitude")       
    dict_points.update(create_dict_points(df, "Receiver name", "Receiver latitude", "Receiver longitude"))
    list_solution, closest_dct = create_solution(df, dict_terminals, dict_points)
    list_clients = []
    for i in list_terminals:
        list_clients += list_solution[i-1]
    list_solution, closest_dct = create_solution_150_20(df, dict_terminals, dict_points)
    list_clients += list_solution[int(closest_dct[-1])-1]
    df  = df[df["Receiver name"].isin(list_clients)]
    df = df[df["Sender weight (kg)"]>5]
#     close_clients = df_test[df_test["DC1"]<10000].index.to_list()
#     df = df[~df["Receiver name"].isin(close_clients)]
    dict_results, df_results_details  = co2_modell(
        df, df_distance_matrix, dict_terminals, date_from, date_to, volume = volume)
    return dict_results, df_results_details, closest_dct, df

# %%
def evaluate_solution_intermodal_combined(df, date_from, date_to, dict_terminals, list_terminals, volume, truck_capacity = truck_capacity):
    df = df[(df["Delivery date"]>=pd.to_datetime(date_from))&(df["Delivery date"]<=pd.to_datetime(date_to))]
    dict_points = create_dict_points(df, "Shipper name", "Shipper latitude", "Shipper longitude")       
    dict_points.update(create_dict_points(df, "Receiver name", "Receiver latitude", "Receiver longitude"))
    list_solution, closest_dct = create_solution(df, dict_terminals, dict_points)
    list_clients = []
    for i in list_terminals:
        list_clients += list_solution[i-1]
    list_solution, closest_dct = create_solution_150_20(df, dict_terminals, dict_points)
    list_clients += list_solution[int(closest_dct[-1])-1]
    list_clients += ["C316"]
    df  = df[df["Receiver name"].isin(list_clients)]
    df = df[df["Sender weight (kg)"]>5]
#     close_clients = df_test[df_test["DC1"]<10000].index.to_list()
#     df = df[~df["Receiver name"].isin(close_clients)]
    dict_results, df_results_details  = co2_modell(
        df, df_distance_matrix, dict_terminals, date_from, date_to, volume = volume)
    return dict_results, df_results_details, closest_dct, df

# %%
def evaluate_solution_intermodal_intermodal(df, date_from, date_to, dict_terminals, list_terminals, volume, truck_capacity = truck_capacity):
    df = df[(df["Delivery date"]>=pd.to_datetime(date_from))&(df["Delivery date"]<=pd.to_datetime(date_to))]
    dict_points = create_dict_points(df, "Shipper name", "Shipper latitude", "Shipper longitude")       
    dict_points.update(create_dict_points(df, "Receiver name", "Receiver latitude", "Receiver longitude"))
    list_solution, closest_dct = create_solution(df, dict_terminals, dict_points)
    list_clients = []
    for i in list_terminals:
        list_clients += list_solution[i-1]
    list_solution, closest_dct = create_solution_150_20(df, dict_terminals, dict_points)
    list_clients += list_solution[int(closest_dct[-1])-1]
    list_clients += ["C316"]
    df  = df[df["Receiver name"].isin(list_clients)]
    df = df[df["Sender weight (kg)"]>5]
#     close_clients = df_test[df_test["DC1"]<10000].index.to_list()
#     df = df[~df["Receiver name"].isin(close_clients)]
    dict_results, df_results_details  = co2_modell(
        df, df_distance_matrix, dict_terminals, date_from, date_to, volume = volume, mode = "intermodal")
    return dict_results, df_results_details, closest_dct, df

# %% [markdown]
# ## 1. Base scenario

# %% [markdown]
# ### Daily

# %%
i = 12

# %%
df_results_daily = get_results_one_month(df_dc1, i, 1, truck_capacity, mode = "combined", algorithm = "base")
# Out:
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# 2023-08-09 16:56:06.156 | INFO     | src.co2_modells:preprocessing_modelling:38 - 244.63400000000001
# 2023-08-09 16:56:06.175 | INFO     | src.co2_modells:co2_modell:71 - 0.7183076923076923
# (307, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning:
#
# Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# (46, 12)
# (100, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_18172\3074107163.py:12: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# 2023-08-09 16:56:15.343 | INFO     | src.co2_modells:preprocessing_modelling:38 - 185.998
# 2023-08-09 16:56:15.362 | INFO     | src.co2_modells:co2_modell:71 - 0.5428461538461539
# Total processing time: 8.9375
# (268, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning:
#
# Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# (42, 12)
# (85, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_18172\3074107163.py:12: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# 2023-08-09 16:56:26.555 | INFO     | src.co2_modells:preprocessing_modelling:38 - nan
# 2023-08-09 16:56:26.570 | INFO     | src.co2_modells:preprocessing_modelling:38 - nan
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# 2023-08-09 16:56:26.579 | INFO     | src.co2_modells:preprocessing_modelling:38 - 181.796
# 2023-08-09 16:56:26.590 | INFO     | src.co2_modells:co2_modell:71 - 0.7421538461538462
# Total processing time: 10.625
# (0, 10)
# No deliveries from 2022-12-03 to 2022-12-04
# (0, 10)
# No deliveries from 2022-12-04 to 2022-12-05
# (312, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning:
#
# Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# (53, 12)
# (106, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_18172\3074107163.py:12: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# 2023-08-09 16:56:37.793 | INFO     | src.co2_modells:preprocessing_modelling:38 - 249.45
# 2023-08-09 16:56:37.818 | INFO     | src.co2_modells:co2_modell:71 - 0.6393846153846154
# Total processing time: 10.46875
# (287, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning:
#
# Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# (43, 12)
# (84, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_18172\3074107163.py:12: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# 2023-08-09 16:56:47.172 | INFO     | src.co2_modells:preprocessing_modelling:38 - 258.384
# 2023-08-09 16:56:47.222 | INFO     | src.co2_modells:co2_modell:71 - 0.624
# Total processing time: 8.265625
# (263, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning:
#
# Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# (42, 12)
# (81, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_18172\3074107163.py:12: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# 2023-08-09 16:56:56.428 | INFO     | src.co2_modells:preprocessing_modelling:38 - 207.058
# 2023-08-09 16:56:56.443 | INFO     | src.co2_modells:co2_modell:71 - 0.6036923076923076
# Total processing time: 8.390625
# (290, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning:
#
# Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# (42, 12)
# (76, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_18172\3074107163.py:12: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# 2023-08-09 16:57:05.646 | INFO     | src.co2_modells:preprocessing_modelling:38 - 171.678
# 2023-08-09 16:57:05.661 | INFO     | src.co2_modells:co2_modell:71 - 0.4402307692307692
# Total processing time: 8.46875
# (228, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning:
#
# Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# (36, 12)
# (78, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_18172\3074107163.py:12: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# 2023-08-09 16:57:15.840 | INFO     | src.co2_modells:preprocessing_modelling:38 - nan
# 2023-08-09 16:57:15.840 | INFO     | src.co2_modells:preprocessing_modelling:38 - nan
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# 2023-08-09 16:57:15.840 | INFO     | src.co2_modells:preprocessing_modelling:38 - 159.326
# 2023-08-09 16:57:15.855 | INFO     | src.co2_modells:co2_modell:71 - 0.6473846153846153
# Total processing time: 9.859375
# (0, 10)
# No deliveries from 2022-12-10 to 2022-12-11
# (0, 10)
# No deliveries from 2022-12-11 to 2022-12-12
# (307, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning:
#
# Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# (43, 12)
# (94, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_18172\3074107163.py:12: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# 2023-08-09 16:57:26.104 | INFO     | src.co2_modells:preprocessing_modelling:38 - 214.918
# 2023-08-09 16:57:26.120 | INFO     | src.co2_modells:co2_modell:71 - 0.6106153846153846
# Total processing time: 9.90625
# (288, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning:
#
# Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# (43, 12)
# (80, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_18172\3074107163.py:12: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# 2023-08-09 16:57:36.334 | INFO     | src.co2_modells:preprocessing_modelling:38 - 181.748
# 2023-08-09 16:57:36.350 | INFO     | src.co2_modells:co2_modell:71 - 0.6610769230769231
# Total processing time: 9.78125
# (276, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning:
#
# Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# (40, 12)
# (85, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_18172\3074107163.py:12: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# 2023-08-09 16:57:46.527 | INFO     | src.co2_modells:preprocessing_modelling:38 - 138.828
# 2023-08-09 16:57:46.543 | INFO     | src.co2_modells:co2_modell:71 - 0.5939230769230769
# Total processing time: 9.875
# (278, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning:
#
# Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# (45, 12)
# (92, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_18172\3074107163.py:12: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# 2023-08-09 16:57:56.794 | INFO     | src.co2_modells:preprocessing_modelling:38 - 150.73399999999998
# 2023-08-09 16:57:56.809 | INFO     | src.co2_modells:co2_modell:71 - 0.4936923076923077
# Total processing time: 9.75
# (263, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning:
#
# Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# (44, 12)
# (77, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_18172\3074107163.py:12: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# 2023-08-09 16:58:07.087 | INFO     | src.co2_modells:preprocessing_modelling:38 - nan
# 2023-08-09 16:58:07.103 | INFO     | src.co2_modells:preprocessing_modelling:38 - nan
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# 2023-08-09 16:58:07.119 | INFO     | src.co2_modells:preprocessing_modelling:38 - 184.0
# 2023-08-09 16:58:07.150 | INFO     | src.co2_modells:co2_modell:71 - 0.4193076923076923
# Total processing time: 9.765625
# (0, 10)
# No deliveries from 2022-12-17 to 2022-12-18
# (0, 10)
# No deliveries from 2022-12-18 to 2022-12-19
# (197, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning:
#
# Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# (26, 12)
# (61, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_18172\3074107163.py:12: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# 2023-08-09 16:58:17.326 | INFO     | src.co2_modells:preprocessing_modelling:38 - 202.852
# 2023-08-09 16:58:17.342 | INFO     | src.co2_modells:co2_modell:71 - 0.521
# Total processing time: 9.890625
# (273, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning:
#
# Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# (51, 12)
# (87, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_18172\3074107163.py:12: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# 2023-08-09 16:58:26.581 | INFO     | src.co2_modells:preprocessing_modelling:38 - 193.03199999999998
# 2023-08-09 16:58:26.597 | INFO     | src.co2_modells:co2_modell:71 - 0.6116923076923076
# Total processing time: 8.90625
# (307, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning:
#
# Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# (43, 12)
# (91, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_18172\3074107163.py:12: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# 2023-08-09 16:58:36.799 | INFO     | src.co2_modells:preprocessing_modelling:38 - 135.62
# 2023-08-09 16:58:36.814 | INFO     | src.co2_modells:co2_modell:71 - 0.44
# Total processing time: 9.84375
# (277, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning:
#
# Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# (51, 12)
# (93, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_18172\3074107163.py:12: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# 2023-08-09 16:58:47.290 | INFO     | src.co2_modells:preprocessing_modelling:38 - 184.0
# 2023-08-09 16:58:47.306 | INFO     | src.co2_modells:co2_modell:71 - 0.6441538461538462
# Total processing time: 9.65625
# (288, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning:
#
# Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# (48, 12)
# (93, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_18172\3074107163.py:12: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# 2023-08-09 16:58:56.760 | INFO     | src.co2_modells:preprocessing_modelling:38 - nan
# 2023-08-09 16:58:56.812 | INFO     | src.co2_modells:preprocessing_modelling:38 - nan
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# 2023-08-09 16:58:56.838 | INFO     | src.co2_modells:preprocessing_modelling:38 - 168.85399999999998
# 2023-08-09 16:58:56.870 | INFO     | src.co2_modells:co2_modell:71 - 0.6501538461538462
# Total processing time: 8.78125
# (0, 10)
# No deliveries from 2022-12-24 to 2022-12-25
# (0, 10)
# No deliveries from 2022-12-25 to 2022-12-26
# (300, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning:
#
# Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# (54, 12)
# (105, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_18172\3074107163.py:12: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# 2023-08-09 16:59:06.065 | INFO     | src.co2_modells:preprocessing_modelling:38 - 135.25
# 2023-08-09 16:59:06.080 | INFO     | src.co2_modells:co2_modell:71 - 0.40192307692307694
# Total processing time: 8.96875
# (240, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning:
#
# Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# (41, 12)
# (81, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_18172\3074107163.py:12: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# 2023-08-09 16:59:16.348 | INFO     | src.co2_modells:preprocessing_modelling:38 - 163.526
# 2023-08-09 16:59:16.366 | INFO     | src.co2_modells:co2_modell:71 - 0.38976923076923076
# Total processing time: 9.9375
# (239, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning:
#
# Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# (41, 12)
# (78, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_18172\3074107163.py:12: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# 2023-08-09 16:59:25.573 | INFO     | src.co2_modells:preprocessing_modelling:38 - 175.976
# 2023-08-09 16:59:25.652 | INFO     | src.co2_modells:co2_modell:71 - 0.5103076923076924
# Total processing time: 8.96875
# (265, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning:
#
# Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# (47, 12)
# (82, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_18172\3074107163.py:12: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# 2023-08-09 16:59:35.929 | INFO     | src.co2_modells:preprocessing_modelling:38 - 158.914
# 2023-08-09 16:59:35.944 | INFO     | src.co2_modells:co2_modell:71 - 0.5394615384615384
# Total processing time: 10.046875
# (263, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning:
#
# Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# (41, 12)
# (81, 16)
# Total processing time: 8.96875
# C:\Users\marle\AppData\Local\Temp\ipykernel_18172\3074107163.py:12: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.

# %%
df_results_daily = get_results_one_month(df_dc1, i, 5, truck_capacity, mode = "combined", algorithm = "base")
# Out:
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# 2023-08-09 16:59:47.221 | INFO     | src.co2_modells:preprocessing_modelling:38 - 1223.17
# 2023-08-09 16:59:47.236 | INFO     | src.co2_modells:co2_modell:71 - 3.6355384615384616
# (307, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning:
#
# Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# (46, 12)
# (100, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_18172\3074107163.py:12: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# 2023-08-09 16:59:56.417 | INFO     | src.co2_modells:preprocessing_modelling:38 - 929.99
# 2023-08-09 16:59:56.433 | INFO     | src.co2_modells:co2_modell:71 - 2.754769230769231
# Total processing time: 8.875
# (268, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning:
#
# Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# (42, 12)
# (85, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_18172\3074107163.py:12: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# 2023-08-09 17:00:07.909 | INFO     | src.co2_modells:preprocessing_modelling:38 - nan
# 2023-08-09 17:00:07.909 | INFO     | src.co2_modells:preprocessing_modelling:38 - nan
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# 2023-08-09 17:00:07.923 | INFO     | src.co2_modells:preprocessing_modelling:38 - 908.98
# 2023-08-09 17:00:07.939 | INFO     | src.co2_modells:co2_modell:71 - 3.7576923076923077
# Total processing time: 10.84375
# (0, 10)
# No deliveries from 2022-12-03 to 2022-12-04
# (0, 10)
# No deliveries from 2022-12-04 to 2022-12-05
# (312, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning:
#
# Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# (53, 12)
# (106, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_18172\3074107163.py:12: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# 2023-08-09 17:00:19.241 | INFO     | src.co2_modells:preprocessing_modelling:38 - 1247.25
# 2023-08-09 17:00:19.256 | INFO     | src.co2_modells:co2_modell:71 - 3.2388461538461537
# Total processing time: 10.9375
# (287, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning:
#
# Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# (43, 12)
# (84, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_18172\3074107163.py:12: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# 2023-08-09 17:00:28.531 | INFO     | src.co2_modells:preprocessing_modelling:38 - 1291.92
# 2023-08-09 17:00:28.594 | INFO     | src.co2_modells:co2_modell:71 - 3.159307692307692
# Total processing time: 8.90625
# (263, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning:
#
# Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# (42, 12)
# (81, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_18172\3074107163.py:12: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# 2023-08-09 17:00:38.006 | INFO     | src.co2_modells:preprocessing_modelling:38 - 1035.29
# 2023-08-09 17:00:38.021 | INFO     | src.co2_modells:co2_modell:71 - 3.0603846153846153
# Total processing time: 8.65625
# (290, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning:
#
# Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# (42, 12)
# (76, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_18172\3074107163.py:12: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# 2023-08-09 17:00:47.593 | INFO     | src.co2_modells:preprocessing_modelling:38 - 858.39
# 2023-08-09 17:00:47.625 | INFO     | src.co2_modells:co2_modell:71 - 2.2333846153846153
# Total processing time: 8.921875
# (228, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning:
#
# Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# (36, 12)
# (78, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_18172\3074107163.py:12: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# 2023-08-09 17:00:57.822 | INFO     | src.co2_modells:preprocessing_modelling:38 - nan
# 2023-08-09 17:00:57.822 | INFO     | src.co2_modells:preprocessing_modelling:38 - nan
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# 2023-08-09 17:00:57.845 | INFO     | src.co2_modells:preprocessing_modelling:38 - 796.63
# 2023-08-09 17:00:57.869 | INFO     | src.co2_modells:co2_modell:71 - 3.276923076923077
# Total processing time: 9.8125
# (0, 10)
# No deliveries from 2022-12-10 to 2022-12-11
# (0, 10)
# No deliveries from 2022-12-11 to 2022-12-12
# (307, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning:
#
# Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# (43, 12)
# (94, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_18172\3074107163.py:12: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# 2023-08-09 17:01:08.174 | INFO     | src.co2_modells:preprocessing_modelling:38 - 1074.59
# 2023-08-09 17:01:08.190 | INFO     | src.co2_modells:co2_modell:71 - 3.0953846153846154
# Total processing time: 9.734375
# (288, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning:
#
# Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# (43, 12)
# (80, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_18172\3074107163.py:12: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# 2023-08-09 17:01:18.511 | INFO     | src.co2_modells:preprocessing_modelling:38 - 908.74
# 2023-08-09 17:01:18.558 | INFO     | src.co2_modells:co2_modell:71 - 3.3416923076923077
# Total processing time: 10.140625
# (276, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning:
#
# Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# (40, 12)
# (85, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_18172\3074107163.py:12: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# 2023-08-09 17:01:28.954 | INFO     | src.co2_modells:preprocessing_modelling:38 - 694.1400000000001
# 2023-08-09 17:01:28.970 | INFO     | src.co2_modells:co2_modell:71 - 3.010846153846154
# Total processing time: 9.953125
# (278, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning:
#
# Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# (45, 12)
# (92, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_18172\3074107163.py:12: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# 2023-08-09 17:01:39.200 | INFO     | src.co2_modells:preprocessing_modelling:38 - 753.67
# 2023-08-09 17:01:39.215 | INFO     | src.co2_modells:co2_modell:71 - 2.5067692307692306
# Total processing time: 9.6875
# (263, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning:
#
# Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# (44, 12)
# (77, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_18172\3074107163.py:12: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# 2023-08-09 17:01:49.498 | INFO     | src.co2_modells:preprocessing_modelling:38 - nan
# 2023-08-09 17:01:49.560 | INFO     | src.co2_modells:preprocessing_modelling:38 - nan
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# 2023-08-09 17:01:49.587 | INFO     | src.co2_modells:preprocessing_modelling:38 - 920.0
# Total processing time: 9.78125
# (0, 10)
# No deliveries from 2022-12-17 to 2022-12-18
# (0, 10)
# No deliveries from 2022-12-18 to 2022-12-19
# (197, 7)
# 2023-08-09 17:01:49.687 | INFO     | src.co2_modells:co2_modell:71 - 2.1253076923076923
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning:
#
# Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# (26, 12)
# (61, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_18172\3074107163.py:12: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# 2023-08-09 17:02:00.103 | INFO     | src.co2_modells:preprocessing_modelling:38 - 1014.26
# 2023-08-09 17:02:00.120 | INFO     | src.co2_modells:co2_modell:71 - 2.645
# Total processing time: 10.0625
# (273, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning:
#
# Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# (51, 12)
# (87, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_18172\3074107163.py:12: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# 2023-08-09 17:02:09.312 | INFO     | src.co2_modells:preprocessing_modelling:38 - 965.16
# 2023-08-09 17:02:09.312 | INFO     | src.co2_modells:co2_modell:71 - 3.1062307692307694
# Total processing time: 8.734375
# (307, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning:
#
# Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# (43, 12)
# (91, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_18172\3074107163.py:12: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# 2023-08-09 17:02:19.517 | INFO     | src.co2_modells:preprocessing_modelling:38 - 678.1
# 2023-08-09 17:02:19.533 | INFO     | src.co2_modells:co2_modell:71 - 2.2433076923076922
# Total processing time: 10.015625
# (277, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning:
#
# Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# (51, 12)
# (93, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_18172\3074107163.py:12: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# 2023-08-09 17:02:29.762 | INFO     | src.co2_modells:preprocessing_modelling:38 - 920.0
# 2023-08-09 17:02:29.778 | INFO     | src.co2_modells:co2_modell:71 - 3.264692307692308
# Total processing time: 9.765625
# (288, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning:
#
# Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# (48, 12)
# (93, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_18172\3074107163.py:12: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# 2023-08-09 17:02:39.099 | INFO     | src.co2_modells:preprocessing_modelling:38 - nan
# 2023-08-09 17:02:39.131 | INFO     | src.co2_modells:preprocessing_modelling:38 - nan
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# 2023-08-09 17:02:39.162 | INFO     | src.co2_modells:preprocessing_modelling:38 - 844.27
# Total processing time: 8.828125
# (0, 10)
# No deliveries from 2022-12-24 to 2022-12-25
# (0, 10)
# No deliveries from 2022-12-25 to 2022-12-26
# (300, 7)
# 2023-08-09 17:02:39.256 | INFO     | src.co2_modells:co2_modell:71 - 3.2965384615384616
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning:
#
# Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# (54, 12)
# (105, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_18172\3074107163.py:12: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# 2023-08-09 17:02:48.486 | INFO     | src.co2_modells:preprocessing_modelling:38 - 676.25
# 2023-08-09 17:02:48.497 | INFO     | src.co2_modells:co2_modell:71 - 2.0465384615384616
# Total processing time: 8.953125
# (240, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning:
#
# Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# (41, 12)
# (81, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_18172\3074107163.py:12: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# 2023-08-09 17:02:59.121 | INFO     | src.co2_modells:preprocessing_modelling:38 - 817.6299999999999
# Total processing time: 9.984375
# 2023-08-09 17:02:59.247 | INFO     | src.co2_modells:co2_modell:71 - 1.983
# (239, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning:
#
# Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# (41, 12)
# (78, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_18172\3074107163.py:12: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# 2023-08-09 17:03:08.421 | INFO     | src.co2_modells:preprocessing_modelling:38 - 879.88
# 2023-08-09 17:03:08.434 | INFO     | src.co2_modells:co2_modell:71 - 2.5884615384615386
# Total processing time: 8.953125
# (265, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning:
#
# Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# (47, 12)
# (82, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_18172\3074107163.py:12: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# 2023-08-09 17:03:18.633 | INFO     | src.co2_modells:preprocessing_modelling:38 - 794.5699999999999
# 2023-08-09 17:03:18.652 | INFO     | src.co2_modells:co2_modell:71 - 2.7366153846153844
# Total processing time: 9.75
# (263, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning:
#
# Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# (41, 12)
# (81, 16)
# Total processing time: 8.796875
# C:\Users\marle\AppData\Local\Temp\ipykernel_18172\3074107163.py:12: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.

# %%
df_results_daily = get_results_one_month(df_dc1, i, 10, truck_capacity, mode = "combined", algorithm = "base")
# Out:
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# 2023-08-09 17:03:29.746 | INFO     | src.co2_modells:preprocessing_modelling:38 - 2446.34
# 2023-08-09 17:03:29.769 | INFO     | src.co2_modells:co2_modell:71 - 7.282846153846154
# (307, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning:
#
# Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# (46, 12)
# (100, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_18172\3074107163.py:12: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# 2023-08-09 17:03:39.023 | INFO     | src.co2_modells:preprocessing_modelling:38 - 1859.98
# 2023-08-09 17:03:39.039 | INFO     | src.co2_modells:co2_modell:71 - 5.519461538461538
# Total processing time: 8.71875
# (268, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning:
#
# Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# (42, 12)
# (85, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_18172\3074107163.py:12: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# 2023-08-09 17:03:50.320 | INFO     | src.co2_modells:preprocessing_modelling:38 - nan
# 2023-08-09 17:03:50.320 | INFO     | src.co2_modells:preprocessing_modelling:38 - nan
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# 2023-08-09 17:03:50.341 | INFO     | src.co2_modells:preprocessing_modelling:38 - 1817.96
# 2023-08-09 17:03:50.368 | INFO     | src.co2_modells:co2_modell:71 - 7.527153846153846
# Total processing time: 10.765625
# (0, 10)
# No deliveries from 2022-12-03 to 2022-12-04
# (0, 10)
# No deliveries from 2022-12-04 to 2022-12-05
# (312, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning:
#
# Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# (53, 12)
# (106, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_18172\3074107163.py:12: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# 2023-08-09 17:04:01.833 | INFO     | src.co2_modells:preprocessing_modelling:38 - 2494.5
# 2023-08-09 17:04:01.849 | INFO     | src.co2_modells:co2_modell:71 - 6.486769230769231
# Total processing time: 10.640625
# (287, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning:
#
# Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# (43, 12)
# (84, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_18172\3074107163.py:12: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# 2023-08-09 17:04:11.020 | INFO     | src.co2_modells:preprocessing_modelling:38 - 2583.84
# 2023-08-09 17:04:11.036 | INFO     | src.co2_modells:co2_modell:71 - 6.329538461538461
# Total processing time: 8.84375
# (263, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning:
#
# Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# (42, 12)
# (81, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_18172\3074107163.py:12: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# 2023-08-09 17:04:20.279 | INFO     | src.co2_modells:preprocessing_modelling:38 - 2070.58
# 2023-08-09 17:04:20.295 | INFO     | src.co2_modells:co2_modell:71 - 6.132153846153846
# Total processing time: 8.90625
# (290, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning:
#
# Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# (42, 12)
# (76, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_18172\3074107163.py:12: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# 2023-08-09 17:04:29.693 | INFO     | src.co2_modells:preprocessing_modelling:38 - 1716.78
# 2023-08-09 17:04:29.740 | INFO     | src.co2_modells:co2_modell:71 - 4.47523076923077
# Total processing time: 9.015625
# (228, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning:
#
# Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# (36, 12)
# (78, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_18172\3074107163.py:12: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# 2023-08-09 17:04:40.161 | INFO     | src.co2_modells:preprocessing_modelling:38 - nan
# 2023-08-09 17:04:40.161 | INFO     | src.co2_modells:preprocessing_modelling:38 - nan
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# 2023-08-09 17:04:40.180 | INFO     | src.co2_modells:preprocessing_modelling:38 - 1593.26
# 2023-08-09 17:04:40.209 | INFO     | src.co2_modells:co2_modell:71 - 6.565307692307693
# Total processing time: 9.9375
# (0, 10)
# No deliveries from 2022-12-10 to 2022-12-11
# (0, 10)
# No deliveries from 2022-12-11 to 2022-12-12
# (307, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning:
#
# Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# (43, 12)
# (94, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_18172\3074107163.py:12: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# 2023-08-09 17:04:50.502 | INFO     | src.co2_modells:preprocessing_modelling:38 - 2149.18
# 2023-08-09 17:04:50.518 | INFO     | src.co2_modells:co2_modell:71 - 6.201307692307692
# Total processing time: 9.8125
# (288, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning:
#
# Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# (43, 12)
# (80, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_18172\3074107163.py:12: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# 2023-08-09 17:05:00.693 | INFO     | src.co2_modells:preprocessing_modelling:38 - 1817.48
# 2023-08-09 17:05:00.724 | INFO     | src.co2_modells:co2_modell:71 - 6.693923076923077
# Total processing time: 9.875
# (276, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning:
#
# Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# (40, 12)
# (85, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_18172\3074107163.py:12: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# 2023-08-09 17:05:11.016 | INFO     | src.co2_modells:preprocessing_modelling:38 - 1388.2800000000002
# 2023-08-09 17:05:11.032 | INFO     | src.co2_modells:co2_modell:71 - 6.031461538461539
# Total processing time: 9.890625
# (278, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning:
#
# Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# (45, 12)
# (92, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_18172\3074107163.py:12: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# 2023-08-09 17:05:21.250 | INFO     | src.co2_modells:preprocessing_modelling:38 - 1507.34
# 2023-08-09 17:05:21.266 | INFO     | src.co2_modells:co2_modell:71 - 5.022615384615385
# Total processing time: 9.546875
# (263, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning:
#
# Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# (44, 12)
# (77, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_18172\3074107163.py:12: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# 2023-08-09 17:05:31.669 | INFO     | src.co2_modells:preprocessing_modelling:38 - nan
# 2023-08-09 17:05:31.691 | INFO     | src.co2_modells:preprocessing_modelling:38 - nan
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# 2023-08-09 17:05:31.710 | INFO     | src.co2_modells:preprocessing_modelling:38 - 1840.0
# 2023-08-09 17:05:31.736 | INFO     | src.co2_modells:co2_modell:71 - 4.257307692307692
# Total processing time: 8.84375
# (0, 10)
# No deliveries from 2022-12-17 to 2022-12-18
# (0, 10)
# No deliveries from 2022-12-18 to 2022-12-19
# (197, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning:
#
# Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# (26, 12)
# (61, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_18172\3074107163.py:12: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# 2023-08-09 17:05:42.070 | INFO     | src.co2_modells:preprocessing_modelling:38 - 2028.52
# 2023-08-09 17:05:42.086 | INFO     | src.co2_modells:co2_modell:71 - 5.301769230769231
# Total processing time: 9.453125
# (273, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning:
#
# Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# (51, 12)
# (87, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_18172\3074107163.py:12: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# 2023-08-09 17:05:51.361 | INFO     | src.co2_modells:preprocessing_modelling:38 - 1930.32
# 2023-08-09 17:05:51.401 | INFO     | src.co2_modells:co2_modell:71 - 6.224153846153846
# Total processing time: 8.765625
# (307, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning:
#
# Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# (43, 12)
# (91, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_18172\3074107163.py:12: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# 2023-08-09 17:06:01.617 | INFO     | src.co2_modells:preprocessing_modelling:38 - 1356.2
# 2023-08-09 17:06:01.648 | INFO     | src.co2_modells:co2_modell:71 - 4.497230769230769
# Total processing time: 9.625
# (277, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning:
#
# Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# (51, 12)
# (93, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_18172\3074107163.py:12: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# 2023-08-09 17:06:12.082 | INFO     | src.co2_modells:preprocessing_modelling:38 - 1840.0
# 2023-08-09 17:06:12.098 | INFO     | src.co2_modells:co2_modell:71 - 6.539153846153846
# Total processing time: 10.125
# (288, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning:
#
# Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# (48, 12)
# (93, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_18172\3074107163.py:12: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# 2023-08-09 17:06:21.279 | INFO     | src.co2_modells:preprocessing_modelling:38 - nan
# 2023-08-09 17:06:21.279 | INFO     | src.co2_modells:preprocessing_modelling:38 - nan
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# 2023-08-09 17:06:21.294 | INFO     | src.co2_modells:preprocessing_modelling:38 - 1688.54
# 2023-08-09 17:06:21.310 | INFO     | src.co2_modells:co2_modell:71 - 6.604461538461538
# Total processing time: 9.0
# (0, 10)
# No deliveries from 2022-12-24 to 2022-12-25
# (0, 10)
# No deliveries from 2022-12-25 to 2022-12-26
# (300, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning:
#
# Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# (54, 12)
# (105, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_18172\3074107163.py:12: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# 2023-08-09 17:06:30.694 | INFO     | src.co2_modells:preprocessing_modelling:38 - 1352.5
# 2023-08-09 17:06:30.710 | INFO     | src.co2_modells:co2_modell:71 - 4.102384615384615
# Total processing time: 9.09375
# (240, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning:
#
# Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# (41, 12)
# (81, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_18172\3074107163.py:12: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# 2023-08-09 17:06:40.962 | INFO     | src.co2_modells:preprocessing_modelling:38 - 1635.2599999999998
# 2023-08-09 17:06:40.962 | INFO     | src.co2_modells:co2_modell:71 - 3.9744615384615383
# Total processing time: 9.921875
# (239, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning:
#
# Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# (41, 12)
# (78, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_18172\3074107163.py:12: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# 2023-08-09 17:06:50.143 | INFO     | src.co2_modells:preprocessing_modelling:38 - 1759.76
# 2023-08-09 17:06:50.159 | INFO     | src.co2_modells:co2_modell:71 - 5.185769230769231
# Total processing time: 8.890625
# (265, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning:
#
# Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# (47, 12)
# (82, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_18172\3074107163.py:12: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# 2023-08-09 17:07:00.362 | INFO     | src.co2_modells:preprocessing_modelling:38 - 1589.1399999999999
# 2023-08-09 17:07:00.377 | INFO     | src.co2_modells:co2_modell:71 - 5.482461538461538
# Total processing time: 9.875
# (263, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning:
#
# Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# (41, 12)
# (81, 16)
# Total processing time: 8.90625
# C:\Users\marle\AppData\Local\Temp\ipykernel_18172\3074107163.py:12: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.

# %% [markdown]
# ### Monday, Wednesday, Friday

# %%
get_results(df_dc1, list_bi_daily, "bidaily", 1, truck_capacity = truck_capacity, mode = "combined", algorithm = "base")
# Out:
# 2023-08-10 08:52:37.935 | INFO     | __main__:get_results:6 - From 2022-01-03 to 2022-01-05
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Sender weight (kg)"] = df["Sender weight (kg)"]*volume
# 2023-08-10 08:52:37.958 | INFO     | src.co2_modells:preprocessing_modelling:38 - 327.554
# 2023-08-10 08:52:37.983 | INFO     | src.co2_modells:co2_modell:71 - 0.9000769230769231
# (326, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   distances['Dmin'] = distances.min(axis=1)
# (59, 12)
# (110, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_12648\1747787820.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_results = df_results.append(dict_results, ignore_index=True)
# 2023-08-10 08:52:48.345 | INFO     | __main__:get_results:6 - From 2022-01-05 to 2022-01-07
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Sender weight (kg)"] = df["Sender weight (kg)"]*volume
# 2023-08-10 08:52:48.361 | INFO     | src.co2_modells:preprocessing_modelling:38 - 309.794
# 2023-08-10 08:52:48.377 | INFO     | src.co2_modells:co2_modell:71 - 1.261
# Total processing time: 3.90625
# (361, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   distances['Dmin'] = distances.min(axis=1)
# (61, 12)
# (120, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_12648\1747787820.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_results = df_results.append(dict_results, ignore_index=True)
# 2023-08-10 08:52:57.833 | INFO     | __main__:get_results:6 - From 2022-01-07 to 2022-01-10
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Sender weight (kg)"] = df["Sender weight (kg)"]*volume
# 2023-08-10 08:52:57.844 | INFO     | src.co2_modells:preprocessing_modelling:38 - 174.74
# 2023-08-10 08:52:57.852 | INFO     | src.co2_modells:co2_modell:71 - 0.564
# Total processing time: 4.1875
# (269, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   distances['Dmin'] = distances.min(axis=1)
# (45, 12)
# (93, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_12648\1747787820.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_results = df_results.append(dict_results, ignore_index=True)
# 2023-08-10 08:53:09.158 | INFO     | __main__:get_results:6 - From 2022-01-10 to 2022-01-12
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Sender weight (kg)"] = df["Sender weight (kg)"]*volume
# 2023-08-10 08:53:09.174 | INFO     | src.co2_modells:preprocessing_modelling:38 - 276.916
# 2023-08-10 08:53:09.205 | INFO     | src.co2_modells:co2_modell:71 - 1.0222307692307693
# Total processing time: 5.1875
# (340, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   distances['Dmin'] = distances.min(axis=1)
# (53, 12)
# (108, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_12648\1747787820.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_results = df_results.append(dict_results, ignore_index=True)
# 2023-08-10 08:53:19.523 | INFO     | __main__:get_results:6 - From 2022-01-12 to 2022-01-14
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Sender weight (kg)"] = df["Sender weight (kg)"]*volume
# 2023-08-10 08:53:19.565 | INFO     | src.co2_modells:preprocessing_modelling:38 - 291.818
# Total processing time: 4.40625
# (375, 7)
# 2023-08-10 08:53:19.775 | INFO     | src.co2_modells:co2_modell:71 - 1.4122307692307692
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   distances['Dmin'] = distances.min(axis=1)
# (62, 12)
# (125, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_12648\1747787820.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_results = df_results.append(dict_results, ignore_index=True)
# 2023-08-10 08:53:30.144 | INFO     | __main__:get_results:6 - From 2022-01-14 to 2022-01-17
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Sender weight (kg)"] = df["Sender weight (kg)"]*volume
# 2023-08-10 08:53:30.152 | INFO     | src.co2_modells:preprocessing_modelling:38 - 156.0
# 2023-08-10 08:53:30.184 | INFO     | src.co2_modells:co2_modell:71 - 0.5243076923076923
# Total processing time: 4.84375
# (262, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   distances['Dmin'] = distances.min(axis=1)
# (43, 12)
# (93, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_12648\1747787820.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_results = df_results.append(dict_results, ignore_index=True)
# 2023-08-10 08:53:40.531 | INFO     | __main__:get_results:6 - From 2022-01-17 to 2022-01-19
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Sender weight (kg)"] = df["Sender weight (kg)"]*volume
# 2023-08-10 08:53:40.564 | INFO     | src.co2_modells:preprocessing_modelling:38 - 332.134
# 2023-08-10 08:53:40.594 | INFO     | src.co2_modells:co2_modell:71 - 1.1427692307692308
# Total processing time: 6.921875
# (368, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   distances['Dmin'] = distances.min(axis=1)
# (59, 12)
# (118, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_12648\1747787820.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_results = df_results.append(dict_results, ignore_index=True)
# 2023-08-10 08:53:50.993 | INFO     | __main__:get_results:6 - From 2022-01-19 to 2022-01-21
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Sender weight (kg)"] = df["Sender weight (kg)"]*volume
# 2023-08-10 08:53:51.009 | INFO     | src.co2_modells:preprocessing_modelling:38 - 301.692
# 2023-08-10 08:53:51.040 | INFO     | src.co2_modells:co2_modell:71 - 1.230846153846154
# Total processing time: 5.125
# (376, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   distances['Dmin'] = distances.min(axis=1)
# (62, 12)
# (123, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_12648\1747787820.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_results = df_results.append(dict_results, ignore_index=True)
# 2023-08-10 08:54:02.426 | INFO     | __main__:get_results:6 - From 2022-01-21 to 2022-01-24
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Sender weight (kg)"] = df["Sender weight (kg)"]*volume
# 2023-08-10 08:54:02.442 | INFO     | src.co2_modells:preprocessing_modelling:38 - 183.642
# 2023-08-10 08:54:02.473 | INFO     | src.co2_modells:co2_modell:71 - 0.6460769230769231
# Total processing time: 5.828125
# (291, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   distances['Dmin'] = distances.min(axis=1)
# (51, 12)
# (105, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_12648\1747787820.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_results = df_results.append(dict_results, ignore_index=True)
# 2023-08-10 08:54:13.749 | INFO     | __main__:get_results:6 - From 2022-01-24 to 2022-01-26
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Sender weight (kg)"] = df["Sender weight (kg)"]*volume
# 2023-08-10 08:54:13.765 | INFO     | src.co2_modells:preprocessing_modelling:38 - 310.58
# 2023-08-10 08:54:13.796 | INFO     | src.co2_modells:co2_modell:71 - 1.2036153846153845
# Total processing time: 5.328125
# (366, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   distances['Dmin'] = distances.min(axis=1)
# (68, 12)
# (128, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_12648\1747787820.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_results = df_results.append(dict_results, ignore_index=True)
# 2023-08-10 08:54:25.148 | INFO     | __main__:get_results:6 - From 2022-01-26 to 2022-01-28
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Sender weight (kg)"] = df["Sender weight (kg)"]*volume
# 2023-08-10 08:54:25.164 | INFO     | src.co2_modells:preprocessing_modelling:38 - 281.986
# 2023-08-10 08:54:25.180 | INFO     | src.co2_modells:co2_modell:71 - 1.1972307692307693
# Total processing time: 5.21875
# (365, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   distances['Dmin'] = distances.min(axis=1)
# (61, 12)
# (125, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_12648\1747787820.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_results = df_results.append(dict_results, ignore_index=True)
# 2023-08-10 08:54:36.516 | INFO     | __main__:get_results:6 - From 2022-01-28 to 2022-01-31
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Sender weight (kg)"] = df["Sender weight (kg)"]*volume
# 2023-08-10 08:54:36.516 | INFO     | src.co2_modells:preprocessing_modelling:38 - 159.708
# 2023-08-10 08:54:36.532 | INFO     | src.co2_modells:co2_modell:71 - 0.639
# Total processing time: 4.5625
# (262, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   distances['Dmin'] = distances.min(axis=1)
# (37, 12)
# (79, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_12648\1747787820.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_results = df_results.append(dict_results, ignore_index=True)
# 2023-08-10 08:54:47.837 | INFO     | __main__:get_results:6 - From 2022-01-31 to 2022-02-02
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Sender weight (kg)"] = df["Sender weight (kg)"]*volume
# 2023-08-10 08:54:47.852 | INFO     | src.co2_modells:preprocessing_modelling:38 - 406.684
# 2023-08-10 08:54:47.900 | INFO     | src.co2_modells:co2_modell:71 - 1.2034615384615384
# Total processing time: 5.515625
# (360, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   distances['Dmin'] = distances.min(axis=1)
# (60, 12)
# (122, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_12648\1747787820.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_results = df_results.append(dict_results, ignore_index=True)
# 2023-08-10 08:54:59.264 | INFO     | __main__:get_results:6 - From 2022-02-02 to 2022-02-04
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Sender weight (kg)"] = df["Sender weight (kg)"]*volume
# 2023-08-10 08:54:59.288 | INFO     | src.co2_modells:preprocessing_modelling:38 - 295.34
# 2023-08-10 08:54:59.311 | INFO     | src.co2_modells:co2_modell:71 - 1.3366923076923076
# Total processing time: 4.796875
# (373, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   distances['Dmin'] = distances.min(axis=1)
# (64, 12)
# (123, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_12648\1747787820.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_results = df_results.append(dict_results, ignore_index=True)
# 2023-08-10 08:55:10.680 | INFO     | __main__:get_results:6 - From 2022-02-04 to 2022-02-07
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Sender weight (kg)"] = df["Sender weight (kg)"]*volume
# 2023-08-10 08:55:10.680 | INFO     | src.co2_modells:preprocessing_modelling:38 - 148.542
# 2023-08-10 08:55:10.712 | INFO     | src.co2_modells:co2_modell:71 - 0.574
# Total processing time: 5.28125
# (300, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   distances['Dmin'] = distances.min(axis=1)
# (54, 12)
# (106, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_12648\1747787820.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_results = df_results.append(dict_results, ignore_index=True)
# 2023-08-10 08:56:53.156 | INFO     | __main__:get_results:6 - From 2022-02-07 to 2022-02-09
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Sender weight (kg)"] = df["Sender weight (kg)"]*volume
# 2023-08-10 08:56:53.156 | INFO     | src.co2_modells:preprocessing_modelling:38 - 293.51
# 2023-08-10 08:56:53.187 | INFO     | src.co2_modells:co2_modell:71 - 1.186
# Total processing time: 5.78125
# (374, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   distances['Dmin'] = distances.min(axis=1)
# (67, 12)
# (128, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_12648\1747787820.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_results = df_results.append(dict_results, ignore_index=True)
# 2023-08-10 08:57:04.655 | INFO     | __main__:get_results:6 - From 2022-02-09 to 2022-02-11
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Sender weight (kg)"] = df["Sender weight (kg)"]*volume
# 2023-08-10 08:57:04.671 | INFO     | src.co2_modells:preprocessing_modelling:38 - 311.202
# 2023-08-10 08:57:04.706 | INFO     | src.co2_modells:co2_modell:71 - 1.3763846153846153
# Total processing time: 7.9375
# (369, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   distances['Dmin'] = distances.min(axis=1)
# (55, 12)
# (120, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_12648\1747787820.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_results = df_results.append(dict_results, ignore_index=True)
# 2023-08-10 08:57:15.160 | INFO     | __main__:get_results:6 - From 2022-02-11 to 2022-02-14
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Sender weight (kg)"] = df["Sender weight (kg)"]*volume
# 2023-08-10 08:57:15.176 | INFO     | src.co2_modells:preprocessing_modelling:38 - 230.51
# 2023-08-10 08:57:15.192 | INFO     | src.co2_modells:co2_modell:71 - 0.6173076923076923
# Total processing time: 6.15625
# (288, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   distances['Dmin'] = distances.min(axis=1)
# (49, 12)
# (96, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_12648\1747787820.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_results = df_results.append(dict_results, ignore_index=True)
# 2023-08-10 08:57:25.549 | INFO     | __main__:get_results:6 - From 2022-02-14 to 2022-02-16
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Sender weight (kg)"] = df["Sender weight (kg)"]*volume
# 2023-08-10 08:57:25.557 | INFO     | src.co2_modells:preprocessing_modelling:38 - 356.672
# 2023-08-10 08:57:25.584 | INFO     | src.co2_modells:co2_modell:71 - 1.3044615384615386
# Total processing time: 7.671875
# (383, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   distances['Dmin'] = distances.min(axis=1)
# (67, 12)
# (128, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_12648\1747787820.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_results = df_results.append(dict_results, ignore_index=True)
# 2023-08-10 08:57:36.922 | INFO     | __main__:get_results:6 - From 2022-02-16 to 2022-02-18
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Sender weight (kg)"] = df["Sender weight (kg)"]*volume
# 2023-08-10 08:57:36.969 | INFO     | src.co2_modells:preprocessing_modelling:38 - 227.536
# 2023-08-10 08:57:36.988 | INFO     | src.co2_modells:co2_modell:71 - 1.2214615384615384
# Total processing time: 8.0625
# (366, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   distances['Dmin'] = distances.min(axis=1)
# (58, 12)
# (119, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_12648\1747787820.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_results = df_results.append(dict_results, ignore_index=True)
# 2023-08-10 08:57:47.333 | INFO     | __main__:get_results:6 - From 2022-02-18 to 2022-02-21
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Sender weight (kg)"] = df["Sender weight (kg)"]*volume
# 2023-08-10 08:57:47.373 | INFO     | src.co2_modells:preprocessing_modelling:38 - 249.72799999999998
# 2023-08-10 08:57:47.396 | INFO     | src.co2_modells:co2_modell:71 - 0.6206923076923077
# Total processing time: 6.5
# (297, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   distances['Dmin'] = distances.min(axis=1)
# (48, 12)
# (98, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_12648\1747787820.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_results = df_results.append(dict_results, ignore_index=True)
# 2023-08-10 08:57:57.946 | INFO     | __main__:get_results:6 - From 2022-02-21 to 2022-02-23
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Sender weight (kg)"] = df["Sender weight (kg)"]*volume
# 2023-08-10 08:57:57.971 | INFO     | src.co2_modells:preprocessing_modelling:38 - 437.846
# 2023-08-10 08:57:58.057 | INFO     | src.co2_modells:co2_modell:71 - 1.2582307692307693
# Total processing time: 5.734375
# (377, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   distances['Dmin'] = distances.min(axis=1)
# (66, 12)
# (128, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_12648\1747787820.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_results = df_results.append(dict_results, ignore_index=True)
# 2023-08-10 08:58:08.565 | INFO     | __main__:get_results:6 - From 2022-02-23 to 2022-02-25
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Sender weight (kg)"] = df["Sender weight (kg)"]*volume
# 2023-08-10 08:58:08.581 | INFO     | src.co2_modells:preprocessing_modelling:38 - 268.002
# 2023-08-10 08:58:08.606 | INFO     | src.co2_modells:co2_modell:71 - 1.2041538461538461
# Total processing time: 5.015625
# (391, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   distances['Dmin'] = distances.min(axis=1)
# (63, 12)
# (126, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_12648\1747787820.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_results = df_results.append(dict_results, ignore_index=True)
# 2023-08-10 08:58:20.038 | INFO     | __main__:get_results:6 - From 2022-02-25 to 2022-02-28
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Sender weight (kg)"] = df["Sender weight (kg)"]*volume
# 2023-08-10 08:58:20.075 | INFO     | src.co2_modells:preprocessing_modelling:38 - 237.026
# 2023-08-10 08:58:20.101 | INFO     | src.co2_modells:co2_modell:71 - 0.5496153846153846
# Total processing time: 7.171875
# (283, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   distances['Dmin'] = distances.min(axis=1)
# (48, 12)
# (89, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_12648\1747787820.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_results = df_results.append(dict_results, ignore_index=True)
# 2023-08-10 08:58:29.515 | INFO     | __main__:get_results:6 - From 2022-02-28 to 2022-03-02
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Sender weight (kg)"] = df["Sender weight (kg)"]*volume
# 2023-08-10 08:58:29.517 | INFO     | src.co2_modells:preprocessing_modelling:38 - 428.154
# 2023-08-10 08:58:29.549 | INFO     | src.co2_modells:co2_modell:71 - 1.2495384615384615
# Total processing time: 5.5
# (379, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   distances['Dmin'] = distances.min(axis=1)
# (62, 12)
# (123, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_12648\1747787820.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_results = df_results.append(dict_results, ignore_index=True)
# 2023-08-10 08:58:40.922 | INFO     | __main__:get_results:6 - From 2022-03-02 to 2022-03-04
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Sender weight (kg)"] = df["Sender weight (kg)"]*volume
# 2023-08-10 08:58:40.922 | INFO     | src.co2_modells:preprocessing_modelling:38 - 326.176
# 2023-08-10 08:58:40.954 | INFO     | src.co2_modells:co2_modell:71 - 1.5673076923076923
# Total processing time: 6.21875
# (402, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   distances['Dmin'] = distances.min(axis=1)
# (68, 12)
# (134, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_12648\1747787820.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_results = df_results.append(dict_results, ignore_index=True)
# 2023-08-10 08:58:52.534 | INFO     | __main__:get_results:6 - From 2022-03-04 to 2022-03-07
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Sender weight (kg)"] = df["Sender weight (kg)"]*volume
# 2023-08-10 08:58:52.550 | INFO     | src.co2_modells:preprocessing_modelling:38 - 215.022
# 2023-08-10 08:58:52.572 | INFO     | src.co2_modells:co2_modell:71 - 0.6182307692307693
# Total processing time: 6.6875
# (291, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   distances['Dmin'] = distances.min(axis=1)
# (51, 12)
# (101, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_12648\1747787820.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_results = df_results.append(dict_results, ignore_index=True)
# 2023-08-10 08:59:03.000 | INFO     | __main__:get_results:6 - From 2022-03-07 to 2022-03-09
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Sender weight (kg)"] = df["Sender weight (kg)"]*volume
# 2023-08-10 08:59:03.039 | INFO     | src.co2_modells:preprocessing_modelling:38 - 288.15
# 2023-08-10 08:59:03.065 | INFO     | src.co2_modells:co2_modell:71 - 1.252
# Total processing time: 6.3125
# (395, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   distances['Dmin'] = distances.min(axis=1)
# (64, 12)
# (127, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_12648\1747787820.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_results = df_results.append(dict_results, ignore_index=True)
# 2023-08-10 08:59:14.455 | INFO     | __main__:get_results:6 - From 2022-03-09 to 2022-03-11
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Sender weight (kg)"] = df["Sender weight (kg)"]*volume
# 2023-08-10 08:59:14.473 | INFO     | src.co2_modells:preprocessing_modelling:38 - 391.144
# 2023-08-10 08:59:14.502 | INFO     | src.co2_modells:co2_modell:71 - 1.5153076923076922
# Total processing time: 6.96875
# (400, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   distances['Dmin'] = distances.min(axis=1)
# (66, 12)
# (127, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_12648\1747787820.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_results = df_results.append(dict_results, ignore_index=True)
# 2023-08-10 08:59:26.008 | INFO     | __main__:get_results:6 - From 2022-03-11 to 2022-03-14
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Sender weight (kg)"] = df["Sender weight (kg)"]*volume
# 2023-08-10 08:59:26.027 | INFO     | src.co2_modells:preprocessing_modelling:38 - 233.29
# 2023-08-10 08:59:26.042 | INFO     | src.co2_modells:co2_modell:71 - 0.8203846153846154
# Total processing time: 8.21875
# (326, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   distances['Dmin'] = distances.min(axis=1)
# (56, 12)
# (105, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_12648\1747787820.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_results = df_results.append(dict_results, ignore_index=True)
# 2023-08-10 08:59:36.346 | INFO     | __main__:get_results:6 - From 2022-03-14 to 2022-03-16
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Sender weight (kg)"] = df["Sender weight (kg)"]*volume
# 2023-08-10 08:59:36.363 | INFO     | src.co2_modells:preprocessing_modelling:38 - 232.09
# 2023-08-10 08:59:36.388 | INFO     | src.co2_modells:co2_modell:71 - 1.046
# Total processing time: 8.0
# (360, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   distances['Dmin'] = distances.min(axis=1)
# (57, 12)
# (117, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_12648\1747787820.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_results = df_results.append(dict_results, ignore_index=True)
# 2023-08-10 08:59:47.761 | INFO     | __main__:get_results:6 - From 2022-03-16 to 2022-03-18
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Sender weight (kg)"] = df["Sender weight (kg)"]*volume
# 2023-08-10 08:59:47.761 | INFO     | src.co2_modells:preprocessing_modelling:38 - 299.08
# 2023-08-10 08:59:47.793 | INFO     | src.co2_modells:co2_modell:71 - 1.5345384615384616
# Total processing time: 8.234375
# (399, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   distances['Dmin'] = distances.min(axis=1)
# (66, 12)
# (132, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_12648\1747787820.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_results = df_results.append(dict_results, ignore_index=True)
# 2023-08-10 08:59:59.187 | INFO     | __main__:get_results:6 - From 2022-03-18 to 2022-03-21
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Sender weight (kg)"] = df["Sender weight (kg)"]*volume
# 2023-08-10 08:59:59.202 | INFO     | src.co2_modells:preprocessing_modelling:38 - 168.332
# 2023-08-10 08:59:59.227 | INFO     | src.co2_modells:co2_modell:71 - 0.6072307692307692
# Total processing time: 5.890625
# (297, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   distances['Dmin'] = distances.min(axis=1)
# (44, 12)
# (92, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_12648\1747787820.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_results = df_results.append(dict_results, ignore_index=True)
# 2023-08-10 09:00:10.550 | INFO     | __main__:get_results:6 - From 2022-03-21 to 2022-03-23
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Sender weight (kg)"] = df["Sender weight (kg)"]*volume
# 2023-08-10 09:00:10.566 | INFO     | src.co2_modells:preprocessing_modelling:38 - 237.92399999999998
# 2023-08-10 09:00:10.581 | INFO     | src.co2_modells:co2_modell:71 - 1.108
# Total processing time: 5.453125
# (367, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   distances['Dmin'] = distances.min(axis=1)
# (58, 12)
# (121, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_12648\1747787820.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_results = df_results.append(dict_results, ignore_index=True)
# 2023-08-10 09:00:22.014 | INFO     | __main__:get_results:6 - From 2022-03-23 to 2022-03-25
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...
#   distances['Dmin'] = distances.min(axis=1)
# (36, 12)
# (78, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_12648\1747787820.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_results = df_results.append(dict_results, ignore_index=True)
# 2023-08-10 09:22:27.459 | INFO     | __main__:get_results:6 - From 2022-12-12 to 2022-12-14
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Sender weight (kg)"] = df["Sender weight (kg)"]*volume
# 2023-08-10 09:22:27.502 | INFO     | src.co2_modells:preprocessing_modelling:38 - 374.244
# 2023-08-10 09:22:27.517 | INFO     | src.co2_modells:co2_modell:71 - 1.2642307692307693
# Total processing time: 4.96875
# (387, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   distances['Dmin'] = distances.min(axis=1)
# (59, 12)
# (121, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_12648\1747787820.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_results = df_results.append(dict_results, ignore_index=True)
# 2023-08-10 09:22:39.092 | INFO     | __main__:get_results:6 - From 2022-12-14 to 2022-12-16
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Sender weight (kg)"] = df["Sender weight (kg)"]*volume
# 2023-08-10 09:22:39.115 | INFO     | src.co2_modells:preprocessing_modelling:38 - 212.98199999999997
# 2023-08-10 09:22:39.140 | INFO     | src.co2_modells:co2_modell:71 - 1.260846153846154
# Total processing time: 6.40625
# (370, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   distances['Dmin'] = distances.min(axis=1)
# (58, 12)
# (118, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_12648\1747787820.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_results = df_results.append(dict_results, ignore_index=True)
# 2023-08-10 09:22:49.568 | INFO     | __main__:get_results:6 - From 2022-12-16 to 2022-12-19
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Sender weight (kg)"] = df["Sender weight (kg)"]*volume
# 2023-08-10 09:22:49.580 | INFO     | src.co2_modells:preprocessing_modelling:38 - 150.73399999999998
# 2023-08-10 09:22:49.592 | INFO     | src.co2_modells:co2_modell:71 - 0.4936923076923077
# Total processing time: 6.328125
# (263, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   distances['Dmin'] = distances.min(axis=1)
# (44, 12)
# (77, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_12648\1747787820.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_results = df_results.append(dict_results, ignore_index=True)
# 2023-08-10 09:22:59.999 | INFO     | __main__:get_results:6 - From 2022-12-19 to 2022-12-21
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Sender weight (kg)"] = df["Sender weight (kg)"]*volume
# 2023-08-10 09:23:00.007 | INFO     | src.co2_modells:preprocessing_modelling:38 - 288.296
# 2023-08-10 09:23:00.048 | INFO     | src.co2_modells:co2_modell:71 - 0.945076923076923
# Total processing time: 4.953125
# (340, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   distances['Dmin'] = distances.min(axis=1)
# (57, 12)
# (110, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_12648\1747787820.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_results = df_results.append(dict_results, ignore_index=True)
# 2023-08-10 09:23:10.481 | INFO     | __main__:get_results:6 - From 2022-12-21 to 2022-12-23
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Sender weight (kg)"] = df["Sender weight (kg)"]*volume
# 2023-08-10 09:23:10.508 | INFO     | src.co2_modells:preprocessing_modelling:38 - 231.584
# 2023-08-10 09:23:10.544 | INFO     | src.co2_modells:co2_modell:71 - 1.0600769230769231
# Total processing time: 6.53125
# (373, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   distances['Dmin'] = distances.min(axis=1)
# (61, 12)
# (120, 16)
#                                    terminal allocation  \
# 0    [[C163, C341, C676, C697, C353, C113, C661, C6...
# 1    [[C163, C676, C850, C697, C113, C1181, C661, C...
# 2    [[C676, C850, C697, C353, C113, C661, C273, C8...
# 3    [[C124, C697, C778, C353, C113, C661, C694, C2...
# 4    [[C676, C850, C124, C697, C778, C353, C113, C6...
# ..                                                 ...
# 150  [[C850, C124, C697, C778, C353, C113, C1181, C...
# 151  [[C676, C850, C124, C697, C778, C353, C113, C1...
# 152  [[C676, C850, C124, C778, C113, C1181, C661, C...
# 153  [[C676, C850, C124, C697, C778, C113, C1181, C...
# 154  [[C676, C124, C697, C353, C113, C1181, C661, C...
#
#                                        routes railroad  \
# 0    {'T1': [['T1', 'C676', 'C163', 'C341', 'C697',...
# 1    {'T1': [['T1', 'C1181', 'C676', 'C850', 'C163'...
# 2    {'T1': [['T1', 'C850', 'C676', 'C353', 'C697',...
# 3    {'T1': [['T1', 'C353', 'C124', 'C697', 'C113',...
# 4    {'T1': [['T1', 'C935', 'C284', 'C238', 'C1025'...
# ..                                                 ...
# 150  {'T1': [['T1', 'C284', 'C238', 'C55', 'C196', ...
# 151  {'T1': [['T1', 'C935', 'C284', 'C1025', 'C565'...
# 152  {'T1': [['T1', 'C935', 'C284', 'C196', 'C55', ...
# 153  {'T1': [['T1', 'C284', 'C238', 'C196', 'C55', ...
# 154  {'T1': [['T1', 'C79', 'C1948', 'C1025', 'C565'...
#
#      processing time railroad  volume
# 0                    3.468750     1.0
# 1                    3.562500     1.0
# 2                    4.796875     1.0
# 3                    4.000000     1.0
# 4                    4.203125     1.0
# ..                        ...     ...
# 150                  5.828125     1.0
# 151                  6.187500     1.0
# 152                  4.609375     1.0
# 153                  5.031250     1.0
# 154                  5.718750     1.0
#
# [155 rows x 12 columns]

# %%
get_results(df_dc1, list_bi_daily, "bidaily", 5, truck_capacity = truck_capacity, mode = "combined", algorithm = "base")
# Out:
# 2023-08-10 09:23:53.379 | INFO     | __main__:get_results:6 - From 2022-01-03 to 2022-01-05
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Sender weight (kg)"] = df["Sender weight (kg)"]*volume
# 2023-08-10 09:23:53.397 | INFO     | src.co2_modells:preprocessing_modelling:38 - 1637.77
# 2023-08-10 09:23:53.411 | INFO     | src.co2_modells:co2_modell:71 - 4.546153846153846
# (326, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   distances['Dmin'] = distances.min(axis=1)
# (59, 12)
# (110, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_12648\1747787820.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_results = df_results.append(dict_results, ignore_index=True)
# 2023-08-10 09:24:03.758 | INFO     | __main__:get_results:6 - From 2022-01-05 to 2022-01-07
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Sender weight (kg)"] = df["Sender weight (kg)"]*volume
# 2023-08-10 09:24:03.774 | INFO     | src.co2_modells:preprocessing_modelling:38 - 1548.97
# 2023-08-10 09:24:03.790 | INFO     | src.co2_modells:co2_modell:71 - 6.358153846153846
# Total processing time: 6.75
# (361, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   distances['Dmin'] = distances.min(axis=1)
# (61, 12)
# (120, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_12648\1747787820.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_results = df_results.append(dict_results, ignore_index=True)
# 2023-08-10 09:24:13.096 | INFO     | __main__:get_results:6 - From 2022-01-07 to 2022-01-10
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Sender weight (kg)"] = df["Sender weight (kg)"]*volume
# 2023-08-10 09:24:13.106 | INFO     | src.co2_modells:preprocessing_modelling:38 - 873.7
# 2023-08-10 09:24:13.127 | INFO     | src.co2_modells:co2_modell:71 - 2.858
# Total processing time: 5.1875
# (269, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   distances['Dmin'] = distances.min(axis=1)
# (45, 12)
# (93, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_12648\1747787820.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_results = df_results.append(dict_results, ignore_index=True)
# 2023-08-10 09:24:24.476 | INFO     | __main__:get_results:6 - From 2022-01-10 to 2022-01-12
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Sender weight (kg)"] = df["Sender weight (kg)"]*volume
# 2023-08-10 09:24:24.486 | INFO     | src.co2_modells:preprocessing_modelling:38 - 1384.58
# 2023-08-10 09:24:24.501 | INFO     | src.co2_modells:co2_modell:71 - 5.1600769230769234
# Total processing time: 6.59375
# (340, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   distances['Dmin'] = distances.min(axis=1)
# (53, 12)
# (108, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_12648\1747787820.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_results = df_results.append(dict_results, ignore_index=True)
# 2023-08-10 09:24:34.791 | INFO     | __main__:get_results:6 - From 2022-01-12 to 2022-01-14
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Sender weight (kg)"] = df["Sender weight (kg)"]*volume
# 2023-08-10 09:24:34.813 | INFO     | src.co2_modells:preprocessing_modelling:38 - 1459.09
# 2023-08-10 09:24:34.839 | INFO     | src.co2_modells:co2_modell:71 - 7.118
# Total processing time: 6.203125
# (375, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   distances['Dmin'] = distances.min(axis=1)
# (62, 12)
# (125, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_12648\1747787820.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_results = df_results.append(dict_results, ignore_index=True)
# 2023-08-10 09:24:45.214 | INFO     | __main__:get_results:6 - From 2022-01-14 to 2022-01-17
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Sender weight (kg)"] = df["Sender weight (kg)"]*volume
# 2023-08-10 09:24:45.239 | INFO     | src.co2_modells:preprocessing_modelling:38 - 780.0
# 2023-08-10 09:24:45.255 | INFO     | src.co2_modells:co2_modell:71 - 2.6573076923076924
# Total processing time: 6.921875
# (262, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   distances['Dmin'] = distances.min(axis=1)
# (43, 12)
# (93, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_12648\1747787820.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_results = df_results.append(dict_results, ignore_index=True)
# 2023-08-10 09:24:55.602 | INFO     | __main__:get_results:6 - From 2022-01-17 to 2022-01-19
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Sender weight (kg)"] = df["Sender weight (kg)"]*volume
# 2023-08-10 09:24:55.643 | INFO     | src.co2_modells:preprocessing_modelling:38 - 1660.67
# 2023-08-10 09:24:55.783 | INFO     | src.co2_modells:co2_modell:71 - 5.768538461538461
# Total processing time: 5.265625
# (368, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   distances['Dmin'] = distances.min(axis=1)
# (59, 12)
# (118, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_12648\1747787820.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_results = df_results.append(dict_results, ignore_index=True)
# 2023-08-10 09:25:06.297 | INFO     | __main__:get_results:6 - From 2022-01-19 to 2022-01-21
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Sender weight (kg)"] = df["Sender weight (kg)"]*volume
# 2023-08-10 09:25:06.316 | INFO     | src.co2_modells:preprocessing_modelling:38 - 1508.46
# 2023-08-10 09:25:06.349 | INFO     | src.co2_modells:co2_modell:71 - 6.206769230769231
# Total processing time: 3.640625
# (376, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   distances['Dmin'] = distances.min(axis=1)
# (62, 12)
# (123, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_12648\1747787820.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_results = df_results.append(dict_results, ignore_index=True)
# 2023-08-10 09:25:17.869 | INFO     | __main__:get_results:6 - From 2022-01-21 to 2022-01-24
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Sender weight (kg)"] = df["Sender weight (kg)"]*volume
# 2023-08-10 09:25:17.887 | INFO     | src.co2_modells:preprocessing_modelling:38 - 918.21
# 2023-08-10 09:25:17.917 | INFO     | src.co2_modells:co2_modell:71 - 3.2717692307692308
# Total processing time: 4.203125
# (291, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   distances['Dmin'] = distances.min(axis=1)
# (51, 12)
# (105, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_12648\1747787820.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_results = df_results.append(dict_results, ignore_index=True)
# 2023-08-10 09:25:29.264 | INFO     | __main__:get_results:6 - From 2022-01-24 to 2022-01-26
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Sender weight (kg)"] = df["Sender weight (kg)"]*volume
# 2023-08-10 09:25:29.276 | INFO     | src.co2_modells:preprocessing_modelling:38 - 1552.9
# 2023-08-10 09:25:29.298 | INFO     | src.co2_modells:co2_modell:71 - 6.072538461538461
# Total processing time: 4.21875
# (366, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   distances['Dmin'] = distances.min(axis=1)
# (68, 12)
# (128, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_12648\1747787820.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_results = df_results.append(dict_results, ignore_index=True)
# 2023-08-10 09:25:40.809 | INFO     | __main__:get_results:6 - From 2022-01-26 to 2022-01-28
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Sender weight (kg)"] = df["Sender weight (kg)"]*volume
# 2023-08-10 09:25:40.827 | INFO     | src.co2_modells:preprocessing_modelling:38 - 1409.93
# 2023-08-10 09:25:40.859 | INFO     | src.co2_modells:co2_modell:71 - 6.038461538461538
# Total processing time: 4.09375
# (365, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   distances['Dmin'] = distances.min(axis=1)
# (61, 12)
# (125, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_12648\1747787820.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_results = df_results.append(dict_results, ignore_index=True)
# 2023-08-10 09:25:52.297 | INFO     | __main__:get_results:6 - From 2022-01-28 to 2022-01-31
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Sender weight (kg)"] = df["Sender weight (kg)"]*volume
# 2023-08-10 09:25:52.318 | INFO     | src.co2_modells:preprocessing_modelling:38 - 798.54
# 2023-08-10 09:25:52.360 | INFO     | src.co2_modells:co2_modell:71 - 3.230923076923077
# Total processing time: 5.25
# (262, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   distances['Dmin'] = distances.min(axis=1)
# (37, 12)
# (79, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_12648\1747787820.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_results = df_results.append(dict_results, ignore_index=True)
# 2023-08-10 09:26:03.683 | INFO     | __main__:get_results:6 - From 2022-01-31 to 2022-02-02
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Sender weight (kg)"] = df["Sender weight (kg)"]*volume
# 2023-08-10 09:26:03.699 | INFO     | src.co2_modells:preprocessing_modelling:38 - 2033.42
# 2023-08-10 09:26:03.748 | INFO     | src.co2_modells:co2_modell:71 - 6.06976923076923
# Total processing time: 7.734375
# (360, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   distances['Dmin'] = distances.min(axis=1)
# (60, 12)
# (122, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_12648\1747787820.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_results = df_results.append(dict_results, ignore_index=True)
# 2023-08-10 09:26:15.127 | INFO     | __main__:get_results:6 - From 2022-02-02 to 2022-02-04
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Sender weight (kg)"] = df["Sender weight (kg)"]*volume
# 2023-08-10 09:26:15.150 | INFO     | src.co2_modells:preprocessing_modelling:38 - 1476.7
# 2023-08-10 09:26:15.220 | INFO     | src.co2_modells:co2_modell:71 - 6.738153846153846
# Total processing time: 7.34375
# (373, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   distances['Dmin'] = distances.min(axis=1)
# (64, 12)
# (123, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_12648\1747787820.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_results = df_results.append(dict_results, ignore_index=True)
# 2023-08-10 09:26:26.554 | INFO     | __main__:get_results:6 - From 2022-02-04 to 2022-02-07
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Sender weight (kg)"] = df["Sender weight (kg)"]*volume
# 2023-08-10 09:26:26.556 | INFO     | src.co2_modells:preprocessing_modelling:38 - 742.71
# 2023-08-10 09:26:26.586 | INFO     | src.co2_modells:co2_modell:71 - 2.9143846153846154
# Total processing time: 6.1875
# (300, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   distances['Dmin'] = distances.min(axis=1)
# (54, 12)
# (106, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_12648\1747787820.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_results = df_results.append(dict_results, ignore_index=True)
# 2023-08-10 09:26:37.960 | INFO     | __main__:get_results:6 - From 2022-02-07 to 2022-02-09
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Sender weight (kg)"] = df["Sender weight (kg)"]*volume
# 2023-08-10 09:26:37.976 | INFO     | src.co2_modells:preprocessing_modelling:38 - 1467.55
# 2023-08-10 09:26:38.007 | INFO     | src.co2_modells:co2_modell:71 - 5.987307692307692
# Total processing time: 5.984375
# (374, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   distances['Dmin'] = distances.min(axis=1)
# (67, 12)
# (128, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_12648\1747787820.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_results = df_results.append(dict_results, ignore_index=True)
# 2023-08-10 09:26:49.376 | INFO     | __main__:get_results:6 - From 2022-02-09 to 2022-02-11
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Sender weight (kg)"] = df["Sender weight (kg)"]*volume
# 2023-08-10 09:26:49.393 | INFO     | src.co2_modells:preprocessing_modelling:38 - 1556.0100000000002
# 2023-08-10 09:26:49.418 | INFO     | src.co2_modells:co2_modell:71 - 6.938153846153846
# Total processing time: 5.546875
# (369, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   distances['Dmin'] = distances.min(axis=1)
# (55, 12)
# (120, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_12648\1747787820.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_results = df_results.append(dict_results, ignore_index=True)
# 2023-08-10 09:26:59.817 | INFO     | __main__:get_results:6 - From 2022-02-11 to 2022-02-14
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Sender weight (kg)"] = df["Sender weight (kg)"]*volume
# 2023-08-10 09:26:59.842 | INFO     | src.co2_modells:preprocessing_modelling:38 - 1152.55
# 2023-08-10 09:26:59.863 | INFO     | src.co2_modells:co2_modell:71 - 3.1266153846153846
# Total processing time: 7.171875
# (288, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   distances['Dmin'] = distances.min(axis=1)
# (49, 12)
# (96, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_12648\1747787820.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_results = df_results.append(dict_results, ignore_index=True)
# 2023-08-10 09:27:10.178 | INFO     | __main__:get_results:6 - From 2022-02-14 to 2022-02-16
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Sender weight (kg)"] = df["Sender weight (kg)"]*volume
# 2023-08-10 09:27:10.199 | INFO     | src.co2_modells:preprocessing_modelling:38 - 1783.3600000000001
# 2023-08-10 09:27:10.220 | INFO     | src.co2_modells:co2_modell:71 - 6.5805384615384614
# Total processing time: 6.96875
# (383, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   distances['Dmin'] = distances.min(axis=1)
# (67, 12)
# (128, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_12648\1747787820.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_results = df_results.append(dict_results, ignore_index=True)
# 2023-08-10 09:27:21.634 | INFO     | __main__:get_results:6 - From 2022-02-16 to 2022-02-18
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Sender weight (kg)"] = df["Sender weight (kg)"]*volume
# 2023-08-10 09
# 153 2022-12-26 11:39:00 2022-12-27 14:25:00  15899.493087      17515175
# 154 2022-12-28 07:16:00 2022-12-29 17:33:00  14042.254861      15325651
#
#                                            routes road  processing time road  \
# 0    [[DC1, C529, C762, C313, C75, C512, C165, C168...              0.593750
# 1    [[DC1, C104, C557, C109, C344, C320, C339, C55...              0.484375
# 2    [[DC1, C768, C451, C762, C470, C82, C236, C143...              0.625000
# 3    [[DC1, C151, C514, C558, C922, C627, C31, C264...              0.484375
# 4    [[DC1, C453, C1650, C922, C353, C73, C697, C67...              0.750000
# ..                                                 ...                   ...
# 150  [[DC1, C1092, C31, C264, C1223, C600, C282, C1...              0.421875
# 151  [[DC1, C514, C922, C627, C63, C167, C635, C509...              0.484375
# 152  [[DC1, C768, C464, C500, C489, C479, C32, C143...              0.406250
# 153  [[DC1, C100, C4167, C160, C734, C691, C320, C1...              0.515625
# 154  [[DC1, C160, C1030, C734, C448, C532, C636, C7...              0.578125
#
#      co2 railroad  distance railroad  \
# 0    13051.854025         17482015.0
# 1    13210.637871         17064855.0
# 2    13029.496283         18320839.0
# 3    13046.776826         17563142.0
# 4    15088.553945         19795873.0
# ..            ...                ...
# 150  13354.095762         17928067.0
# 151  14480.851807         19019156.0
# 152  12230.576517         16108487.0
# 153  13619.443879         18227155.0
# 154  13184.063717         17746760.0
#
#                                    terminal allocation  \
# 0    [[C163, C341, C676, C697, C353, C113, C661, C6...
# 1    [[C163, C676, C850, C697, C113, C1181, C661, C...
# 2    [[C676, C850, C697, C353, C113, C661, C273, C8...
# 3    [[C124, C697, C778, C353, C113, C661, C694, C2...
# 4    [[C676, C850, C124, C697, C778, C353, C113, C6...
# ..                                                 ...
# 150  [[C850, C124, C697, C778, C353, C113, C1181, C...
# 151  [[C676, C850, C124, C697, C778, C353, C113, C1...
# 152  [[C676, C850, C124, C778, C113, C1181, C661, C...
# 153  [[C676, C850, C124, C697, C778, C113, C1181, C...
# 154  [[C676, C124, C697, C353, C113, C1181, C661, C...
#
#                                        routes railroad  \
# 0    {'T1': [['T1', 'C676', 'C163', 'C341', 'C697',...
# 1    {'T1': [['T1', 'C1181', 'C676', 'C850', 'C163'...
# 2    {'T1': [['T1', 'C850', 'C676', 'C353', 'C697',...
# 3    {'T1': [['T1', 'C353', 'C124', 'C697', 'C113',...
# 4    {'T1': [['T1', 'C935', 'C284', 'C238', 'C1025'...
# ..                                                 ...
# 150  {'T1': [['T1', 'C284', 'C238', 'C55', 'C196', ...
# 151  {'T1': [['T1', 'C935', 'C284', 'C1025', 'C565'...
# 152  {'T1': [['T1', 'C935', 'C284', 'C196', 'C55', ...
# 153  {'T1': [['T1', 'C284', 'C238', 'C196', 'C55', ...
# 154  {'T1': [['T1', 'C79', 'C1948', 'C1025', 'C565'...
#
#      processing time railroad  volume
# 0                    6.156250     5.0
# 1                    4.703125     5.0
# 2                    5.968750     5.0
# 3                    5.718750     5.0
# 4                    6.171875     5.0
# ..                        ...     ...
# 150                  3.031250     5.0
# 151                  2.921875     5.0
# 152                  2.640625     5.0
# 153                  4.093750     5.0
# 154                  5.203125     5.0
#
# [155 rows x 12 columns]

# %%
get_results(df_dc1, list_bi_daily, "bidaily", 10, truck_capacity = truck_capacity, mode = "combined", algorithm = "base")
# Out:
# 2023-08-10
[[C676, C850, C124, C697, C778, C353, C113, C1...
# 152  [[C676, C850, C124, C778, C113, C1181, C661, C...
# 153  [[C676, C850, C124, C697, C778, C113, C1181, C...
# 154  [[C676, C124, C697, C353, C113, C1181, C661, C...
#
#                                        routes railroad  \
# 0    {'T1': [['T1', 'C284', 'C238', 'T1'], ['T1', '...
# 1    {'T1': [['T1', 'C1181', 'C676', 'C850', 'C163'...
# 2    {'T1': [['T1', 'C850', 'C676', 'C353', 'C697',...
# 3    {'T1': [['T1', 'C353', 'C124', 'C697', 'C113',...
# 4    {'T1': [['T1', 'C284', 'C238', 'C1025', 'C73',...
# ..                                                 ...
# 150  {'T1': [['T1', 'C284', 'C238', 'C55', 'C196', ...
# 151  {'T1': [['T1', 'C935', 'C284', 'C196', 'C55', ...
# 152  {'T1': [['T1', 'C935', 'C284', 'C196', 'C55', ...
# 153  {'T1': [['T1', 'C284', 'C238', 'C1948', 'C1025...
# 154  {'T1': [['T1', 'C79', 'C1948', 'C1025', 'C565'...
#
#      processing time railroad  volume
# 0                    8.906250    10.0
# 1                    7.062500    10.0
# 2                    9.296875    10.0
# 3                    7.546875    10.0
# 4                    7.937500    10.0
# ..                        ...     ...
# 150                  9.062500    10.0
# 151                  8.765625    10.0
# 152                  7.812500    10.0
# 153                  8.359375    10.0
# 154                  8.437500    10.0
#
# [155 rows x 12 columns]

# %%
df_test = bi_daily_algorithm(df_dc1, list_bi_daily[:4], 1, truck_capacity, mode = "combined", algorithm = "base")
df_test2 = bi_daily_algorithm(df_dc1, list_bi_daily[3:6], 1,truck_capacity, mode = "combined", algorithm = "base")

# %%
list_bi_daily[:6]

# %% [markdown]
# > not always better. In some cases even worse. Vielleicht doch lohnenswert, anzuschauen wie es sich lohnt, wenn nur manche Terminals genutzt werden

# %% [markdown]
# ### Weekly

# %% [markdown]
# > Always better

# %%
get_results(df_dc1, list_mondays, "weekly", 1, truck_capacity = truck_capacity, mode = "combined", algorithm = "base")
# Out:
# 2023-08-10 07:39:53.989 | INFO     | __main__:get_results:6 - From 2022-01-03 to 2022-01-10
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Sender weight (kg)"] = df["Sender weight (kg)"]*volume
# 2023-08-10 07:39:54.017 | INFO     | src.co2_modells:preprocessing_modelling:38 - 547.512
# 2023-08-10 07:39:54.047 | INFO     | src.co2_modells:co2_modell:71 - 2.7426153846153847
# (436, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   distances['Dmin'] = distances.min(axis=1)
# (77, 12)
# (151, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_12648\1747787820.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_results = df_results.append(dict_results, ignore_index=True)
# 2023-08-10 07:40:06.783 | INFO     | __main__:get_results:6 - From 2022-01-10 to 2022-01-17
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Sender weight (kg)"] = df["Sender weight (kg)"]*volume
# 2023-08-10 07:40:06.803 | INFO     | src.co2_modells:preprocessing_modelling:38 - 523.0740000000001
# 2023-08-10 07:40:06.866 | INFO     | src.co2_modells:co2_modell:71 - 2.977692307692308
# Total processing time: 8.71875
# (450, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   distances['Dmin'] = distances.min(axis=1)
# (77, 12)
# (149, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_12648\1747787820.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_results = df_results.append(dict_results, ignore_index=True)
# 2023-08-10 07:40:18.320 | INFO     | __main__:get_results:6 - From 2022-01-17 to 2022-01-24
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Sender weight (kg)"] = df["Sender weight (kg)"]*volume
# 2023-08-10 07:40:18.352 | INFO     | src.co2_modells:preprocessing_modelling:38 - 726.5
# 2023-08-10 07:40:18.384 | INFO     | src.co2_modells:co2_modell:71 - 3.040769230769231
# Total processing time: 7.5
# (455, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   distances['Dmin'] = distances.min(axis=1)
# (80, 12)
# (154, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_12648\1747787820.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_results = df_results.append(dict_results, ignore_index=True)
# 2023-08-10 07:40:29.773 | INFO     | __main__:get_results:6 - From 2022-01-24 to 2022-01-31
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Sender weight (kg)"] = df["Sender weight (kg)"]*volume
# 2023-08-10 07:40:29.789 | INFO     | src.co2_modells:preprocessing_modelling:38 - 594.322
# 2023-08-10 07:40:29.836 | INFO     | src.co2_modells:co2_modell:71 - 3.0585384615384617
# Total processing time: 8.078125
# (447, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   distances['Dmin'] = distances.min(axis=1)
# (79, 12)
# (153, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_12648\1747787820.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_results = df_results.append(dict_results, ignore_index=True)
# 2023-08-10 07:40:41.272 | INFO     | __main__:get_results:6 - From 2022-01-31 to 2022-02-07
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Sender weight (kg)"] = df["Sender weight (kg)"]*volume
# 2023-08-10 07:40:41.281 | INFO     | src.co2_modells:preprocessing_modelling:38 - 551.2620000000001
# 2023-08-10 07:40:41.330 | INFO     | src.co2_modells:co2_modell:71 - 3.135076923076923
# Total processing time: 7.875
# (462, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   distances['Dmin'] = distances.min(axis=1)
# (79, 12)
# (155, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_12648\1747787820.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_results = df_results.append(dict_results, ignore_index=True)
# 2023-08-10 07
{'T1': [['T1', 'C1181', 'C694', 'C661', 'C2098...
# 25  {'T1': [['T1', 'C55', 'C637', 'C883', 'C1181',...
# 26  {'T1': [['T1', 'C55', 'C196', 'C338', 'C637', ...
# 27  {'T1': [['T1', 'C935', 'C284', 'C55', 'T1'], [...
# 28  {'T1': [['T1', 'C867', 'C79', 'C1948', 'C1025'...
# 29  {'T1': [['T1', 'C867', 'C79', 'C1948', 'C1025'...
# 30  {'T1': [['T1', 'C1181', 'C694', 'C661', 'C2098...
# 31  {'T1': [['T1', 'C867', 'C79', 'C1948', 'C1025'...
# 32  {'T1': [['T1', 'C1181', 'C676', 'C850', 'C124'...
# 33  {'T1': [['T1', 'C935', 'C284', 'C238', 'C196',...
# 34  {'T1': [['T1', 'C867', 'C79', 'C1948', 'C1025'...
# 35  {'T1': [['T1', 'C867', 'C79', 'C1948', 'C1025'...
# 36  {'T1': [['T1', 'C935', 'C284', 'C238', 'C196',...
# 37  {'T1': [['T1', 'C1181', 'C661', 'C694', 'C2098...
# 38  {'T1': [['T1', 'C867', 'C79', 'C1948', 'C1025'...
# 39  {'T1': [['T1', 'C55', 'C196', 'C338', 'C637', ...
# 40  {'T1': [['T1', 'C935', 'C284', 'C617', 'C1017'...
# 41  {'T1': [['T1', 'C1181', 'C694', 'C661', 'C637'...
# 42  {'T1': [['T1', 'C935', 'C284', 'C238', 'C1049'...
# 43  {'T1': [['T1', 'C867', 'C79', 'C1948', 'C1025'...
# 44  {'T1': [['T1', 'C867', 'C79', 'C1948', 'C1025'...
# 45  {'T1': [['T1', 'C1181', 'C661', 'C694', 'C2098...
# 46  {'T1': [['T1', 'C935', 'C284', 'C238', 'C196',...
# 47  {'T1': [['T1', 'C1017', 'C2241', 'C425', 'C410...
# 48  {'T1': [['T1', 'C55', 'C196', 'C338', 'C637', ...
# 49  {'T1': [['T1', 'C935', 'C284', 'C238', 'C1948'...
# 50  {'T1': [['T1', 'C55', 'C196', 'C338', 'C637', ...
# 51  {'T1': [['T1', 'C935', 'C284', 'C238', 'C55', ...
#
#     processing time railroad  volume
# 0                   5.750000     5.0
# 1                   5.937500     5.0
# 2                   6.000000     5.0
# 3                   5.828125     5.0
# 4                   6.203125     5.0
# 5                   6.531250     5.0
# 6                   6.437500     5.0
# 7                   6.156250     5.0
# 8                   5.812500     5.0
# 9                   5.390625     5.0
# 10                  5.437500     5.0
# 11                  6.187500     5.0
# 12                  7.031250     5.0
# 13                  6.156250     5.0
# 14                  8.312500     5.0
# 15                  8.875000     5.0
# 16                  6.890625     5.0
# 17                  6.187500     5.0
# 18                  7.046875     5.0
# 19                  6.765625     5.0
# 20                  5.906250     5.0
# 21                  7.421875     5.0
# 22                  7.437500     5.0
# 23                  7.109375     5.0
# 24                  6.812500     5.0
# 25                  6.781250     5.0
# 26                  6.140625     5.0
# 27                  4.437500     5.0
# 28                  3.234375     5.0
# 29                  2.984375     5.0
# 30                  6.109375     5.0
# 31                  6.953125     5.0
# 32                  7.875000     5.0
# 33                  8.203125     5.0
# 34                  6.718750     5.0
# 35                  6.515625     5.0
# 36                  7.250000     5.0
# 37                  8.031250     5.0
# 38                  6.750000     5.0
# 39                  6.687500     5.0
# 40                  6.109375     5.0
# 41                  8.328125     5.0
# 42                  8.406250     5.0
# 43                  7.609375     5.0
# 44                  6.437500     5.0
# 45                  7.156250     5.0
# 46                  6.375000     5.0
# 47                  6.296875     5.0
# 48                  6.390625     5.0
# 49                  6.000000     5.0
# 50                  5.140625     5.0
# 51                  5.359375     5.0

# %%
get_results(df_dc1, list_mondays, "weekly", 10, truck_capacity = truck_capacity, mode = "combined", algorithm = "base")
# Out:
# 2023-08-10 08:41:25.374 | INFO     | __main__:get_results:6 - From 2022-01-03 to 2022-01-10
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Sender weight (kg)"] = df["Sender weight (kg)"]*volume
# 2023-08-10 08:41:25.390 | INFO     | src.co2_modells:preprocessing_modelling:38 - 5475.12
# 2023-08-10 08:41:25.429 | INFO     | src.co2_modells:co2_modell:71 - 27.578846153846154
# (436, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   distances['Dmin'] = distances.min(axis=1)
# (77, 12)
# (151, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_12648\1747787820.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_results = df_results.append(dict_results, ignore_index=True)
# 2023-08-10 08:41:36.985 | INFO     | __main__:get_results:6 - From 2022-01-10 to 2022-01-17
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Sender weight (kg)"] = df["Sender weight (kg)"]*volume
# 2023-08-10 08:41:37.003 | INFO     | src.co2_modells:preprocessing_modelling:38 - 5230.74
# 2023-08-10 08:41:37.058 | INFO     | src.co2_modells:co2_modell:71 - 29.925384615384615
# Total processing time: 6.359375
# (450, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   distances['Dmin'] = distances.min(axis=1)
# (77, 12)
# (149, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_12648\1747787820.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_results = df_results.append(dict_results, ignore_index=True)
# 2023-08-10 08:41:48.584 | INFO     | __main__:get_results:6 - From 2022-01-17 to 2022-01-24
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Sender weight (kg)"] = df["Sender weight (kg)"]*volume
# 2023-08-10 08:41:48.616 | INFO     | src.co2_modells:preprocessing_modelling:38 - 7265.0
# 2023-08-10 08:41:48.657 | INFO     | src.co2_modells:co2_modell:71 - 30.553153846153847
# Total processing time: 8.203125
# (455, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   distances['Dmin'] = distances.min(axis=1)
# (80, 12)
# (154, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_12648\1747787820.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_results = df_results.append(dict_results, ignore_index=True)
# 2023-08-10 08:42:00.536 | INFO     | __main__:get_results:6 - From 2022-01-24 to 2022-01-31
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Sender weight (kg)"] = df["Sender weight (kg)"]*volume
# 2023-08-10 08:42:00.565 | INFO     | src.co2_modells:preprocessing_modelling:38 - 5943.22
# 2023-08-10 08:42:00.601 | INFO     | src.co2_modells:co2_modell:71 - 30.738230769230768
# Total processing time: 5.15625
# (447, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   distances['Dmin'] = distances.min(axis=1)
# (79, 12)
# (153, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_12648\1747787820.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_results = df_results.append(dict_results, ignore_index=True)
# 2023-08-10 08:42:12.104 | INFO     | __main__:get_results:6 - From 2022-01-31 to 2022-02-07
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Sender weight (kg)"] = df["Sender weight (kg)"]*volume
# 2023-08-10 08:42:12.119 | INFO     | src.co2_modells:preprocessing_modelling:38 - 5512.62
# 2023-08-10 08:42:12.135 | INFO     | src.co2_modells:co2_modell:71 - 31.50523076923077
# Total processing time: 5.0
# (462, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   distances['Dmin'] = distances.min(axis=1)
# (79, 12)
# (155, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_12648\1747787820.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_results = df_results.append(dict_results, ignore_index=True)
# 2023-08-10 08:42:23.653 | INFO     | __main__:get_results:6 - From 2022-02-07 to 2022-02-14
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Sender weight (kg)"] = df["Sender weight (kg)"]*volume
# 2023-08-10 08:42:23.669 | INFO     | src.co2_modells:preprocessing_modelling:38 - 5604.46
# 2023-08-10 08:42:23.700 | INFO     | src.co2_modells:co2_modell:71 - 32.163923076923076
# Total processing time: 5.578125
# (456, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   distances['Dmin'] = distances.min(axis=1)
# (73, 12)
# (151, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_12648\1747787820.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_results = df_results.append(dict_results, ignore_index=True)
# 2023-08-10 08:42:35.436 | INFO     | __main__:get_results:6 - From 2022-02-14 to 2022-02-21
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Sender weight (kg)"] = df["Sender weight (kg)"]*volume
# 2023-08-10 08:42:35.452 | INFO     | src.co2_modells:preprocessing_modelling:38 - 6788.82
# 2023-08-10 08:42:35.483 | INFO     | src.co2_modells:co2_modell:71 - 31.83523076923077
# Total processing time: 6.40625
# (458, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   distances['Dmin'] = distances.min(axis=1)
# (79, 12)
# (154, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_12648\1747787820.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_results = df_results.append(dict_results, ignore_index=True)
# 2023-08-10 08:42:47.160 | INFO     | __main__:get_results:6 - From 2022-02-21 to 2022-02-28
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Sender weight (kg)"] = df["Sender weight (kg)"]*volume
# 2023-08-10 08:42:47.177 | INFO     | src.co2_modells:preprocessing_modelling:38 - 7792.78
# 2023-08-10 08:42:47.217 | INFO     | src.co2_modells:co2_modell:71 - 30.484923076923078
# Total processing time: 5.5625
# (456, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   distances['Dmin'] = distances.min(axis=1)
# (76, 12)
# (148, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_12648\1747787820.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_results = df_results.append(dict_results, ignore_index=True)
# 2023-08-10 08:42:58.693 | INFO     | __main__:get_results:6 - From 2022-02-28 to 2022-03-07
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Sender weight (kg)"] = df["Sender weight (kg)"]*volume
# 2023-08-10 08:42:58.709 | INFO     | src.co2_modells:preprocessing_modelling:38 - 8093.1
# 2023-08-10 08:42:58.742 | INFO     | src.co2_modells:co2_modell:71 - 34.71923076923077
# Total processing time: 4.609375
# (467, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   distances['Dmin'] = distances.min(axis=1)
# (80, 12)
# (157, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_12648\1747787820.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_results = df_results.append(dict_results, ignore_index=True)
# 2023-08-10 08:43:10.216 | INFO     | __main__:get_results:6 - From 2022-03-07 to 2022-03-14
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Sender weight (kg)"] = df["Sender weight (kg)"]*volume
# 2023-08-10 08:43:10.232 | INFO     | src.co2_modells:preprocessing_modelling:38 - 7348.66
# 2023-08-10 08:43:10.262 | INFO     | src.co2_modells:co2_modell:71 - 36.26007692307692
# Total processing time: 4.0
# (475, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   distances['Dmin'] = distances.min(axis=1)
# (81, 12)
# (156, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_12648\1747787820.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_results = df_results.append(dict_results, ignore_index=True)
# 2023-08-10 08:43:21.983 | INFO     | __main__:get_results:6 - From 2022-03-14 to 2022-03-21
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Sender weight (kg)"] = df["Sender weight (kg)"]*volume
# 2023-08-10 08:43:22.007 | INFO     | src.co2_modells:preprocessing_modelling:38 - 5145.12
# 2023-08-10 08:43:22.048 | INFO     | src.co2_modells:co2_modell:71 - 32.24353846153846
# Total processing time: 7.140625
# (455, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   distances['Dmin'] = distances.min(axis=1)
# (76, 12)
# (153, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_12648\1747787820.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_results = df_results.append(dict_results, ignore_index=True)
# 2023-08-10 08:43:33.568 | INFO     | __main__:get_results:6 - From 2022-03-21 to 2022-03-28
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Sender weight (kg)"] = df["Sender weight (kg)"]*volume
# 2023-08-10 08:43:33.584 | INFO     | src.co2_modells:preprocessing_modelling:38 - 7099.96
# 2023-08-10 08:43:33.616 | INFO     | src.co2_modells:co2_modell:71 - 30.923538461538463
# Total processing time: 6.625
# (465, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   distances['Dmin'] = distances.min(axis=1)
# (76, 12)
# (150, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_12648\1747787820.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_results = df_results.append(dict_results, ignore_index=True)
# 2023-08-10 08:43:45.115 | INFO     | __main__:get_results:6 - From 2022-03-28 to 2022-04-04
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Sender weight (kg)"] = df["Sender weight (kg)"]*volume
# 2023-08-10 08:43:45.131 | INFO     | src.co2_modells:preprocessing_modelling:38 - 5896.92
# 2023-08-10 08:43:45.162 | INFO     | src.co2_modells:co2_modell:71 - 37.23323076923077
# Total processing time: 6.515625
# (480, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   distances['Dmin'] = distances.min(axis=1)
# (83, 12)
# (158, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_12648\1747787820.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_results = df_results.append(dict_results, ignore_index=True)
# 2023-08-10 08
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Sender weight (kg)"] = df["Sender weight (kg)"]*volume
# 2023-08-10 08:46:02.007 | INFO     | src.co2_modells:preprocessing_modelling:38 - 6104.3
# 2023-08-10 08:46:02.054 | INFO     | src.co2_modells:co2_modell:71 - 35.63076923076923
# Total processing time: 5.359375
# (485, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   distances['Dmin'] = distances.min(axis=1)
# (82, 12)
# (158, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_12648\1747787820.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_results = df_results.append(dict_results, ignore_index=True)
# 2023-08-10 08:46:13.934 | INFO     | __main__:get_results:6 - From 2022-06-20 to 2022-06-27
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Sender weight (kg)"] = df["Sender weight (kg)"]*volume
# 2023-08-10 08:46:13.965 | INFO     | src.co2_modells:preprocessing_modelling:38 - 6173.62
# Total processing time: 7.046875
# (484, 7)
# 2023-08-10 08:46:14.032 | INFO     | src.co2_modells:co2_modell:71 - 37.21230769230769
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   distances['Dmin'] = distances.min(axis=1)
# (85, 12)
# (161, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_12648\1747787820.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_results = df_results.append(dict_results, ignore_index=True)
# 2023-08-10 08:46:26.071 | INFO     | __main__:get_results:6 - From 2022-06-27 to 2022-07-04
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Sender weight (kg)"] = df["Sender weight (kg)"]*volume
# 2023-08-10 08:46:26.087 | INFO     | src.co2_modells:preprocessing_modelling:38 - 5710.96
# 2023-08-10 08:46:26.134 | INFO     | src.co2_modells:co2_modell:71 - 35.014538461538464
# Total processing time: 5.84375
# (480, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   distances['Dmin'] = distances.min(axis=1)
# (84, 12)
# (162, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_12648\1747787820.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_results = df_results.append(dict_results, ignore_index=True)
# 2023-08-10 08:46:37.705 | INFO     | __main__:get_results:6 - From 2022-07-04 to 2022-07-11
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Sender weight (kg)"] = df["Sender weight (kg)"]*volume
# 2023-08-10 08:46:37.721 | INFO     | src.co2_modells:preprocessing_modelling:38 - 7656.84
# 2023-08-10 08:46:37.768 | INFO     | src.co2_modells:co2_modell:71 - 32.63230769230769
# Total processing time: 5.34375
# (458, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   distances['Dmin'] = distances.min(axis=1)
# (79, 12)
# (150, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_12648\1747787820.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_results = df_results.append(dict_results, ignore_index=True)
# 2023-08-10 08:46:49.437 | INFO     | __main__:get_results:6 - From 2022-07-11 to 2022-07-18
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Sender weight (kg)"] = df["Sender weight (kg)"]*volume
# 2023-08-10 08:46:49.469 | INFO     | src.co2_modells:preprocessing_modelling:38 - 7164.46
# 2023-08-10 08:46:49.517 | INFO     | src.co2_modells:co2_modell:71 - 25.916384615384615
# Total processing time: 5.984375
# (454, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   distances['Dmin'] = distances.min(axis=1)
# (78, 12)
# (148, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_12648\1747787820.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_results = df_results.append(dict_results, ignore_index=True)
# 2023-08-10 08:47:01.225 | INFO     | __main__:get_results:6 - From 2022-07-18 to 2022-07-25
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Sender weight (kg)"] = df["Sender weight (kg)"]*volume
# 2023-08-10 08:47:01.240 | INFO     | src.co2_modells:preprocessing_modelling:38 - 7848.82
# 2023-08-10 08:47:01.299 | INFO     | src.co2_modells:co2_modell:71 - 31.937076923076923
# Total processing time: 7.578125
# (462, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   distances['Dmin'] = distances.min(axis=1)
# (82, 12)
# (157, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_12648\1747787820.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_results = df_results.append(dict_results, ignore_index=True)
# 2023-08-10 08:47:11.884 | INFO     | __main__:get_results:6 - From 2022-07-25 to 2022-08-01
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Sender weight (kg)"] = df["Sender weight (kg)"]*volume
# 2023-08-10 08:47:11.918 | INFO     | src.co2_modells:preprocessing_modelling:38 - 8034.7
# 2023-08-10 08:47:11.947 | INFO     | src.co2_modells:co2_modell:71 - 30.376615384615384
# Total processing time: 6.953125
# (463, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   distances['Dmin'] = distances.min(axis=1)
# (77, 12)
# (154, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_12648\1747787820.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_results = df_results.append(dict_results, ignore_index=True)
# 2023-08-10 08:47:23.501 | INFO     | __main__:get_results:6 - From 2022-08-01 to 2022-08-08
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Sender weight (kg)"] = df["Sender weight (kg)"]*volume
# 2023-08-10 08:47:23.514 | INFO     | src.co2_modells:preprocessing_modelling:38 - 6846.86
# 2023-08-10 08:47:23.558 | INFO     | src.co2_modells:co2_modell:71 - 30.351769230769232
# Total processing time: 6.234375
# (453, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   distances['Dmin'] = distances.min(axis=1)
# (81, 12)
# (152, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_12648\1747787820.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_results = df_results.append(dict_results, ignore_index=True)
# 2023-08-10 08:47:35.081 | INFO     | __main__:get_results:6 - From 2022-08-08 to 2022-08-15
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Sender weight (kg)"] = df["Sender weight (kg)"]*volume
# 2023-08-10 08:47:35.105 | INFO     | src.co2_modells:preprocessing_modelling:38 - 6154.34
# 2023-08-10 08:47:35.133 | INFO     | src.co2_modells:co2_modell:71 - 24.41169230769231
# Total processing time: 6.078125
# (423, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   distances['Dmin'] = distances.min(axis=1)
# (73, 12)
# (141, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_12648\1747787820.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_results = df_results.append(dict_results, ignore_index=True)
# 2023-08-10 08:47:46.810 | INFO     | __main__:get_results:6 - From 2022-08-15 to 2022-08-22
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Sender weight (kg)"] = df["Sender weight (kg)"]*volume
# 2023-08-10 08:47:46.835 | INFO     | src.co2_modells:preprocessing_modelling:38 - 4718.58
# 2023-08-10 08:47:46.857 | INFO     | src.co2_modells:co2_modell:71 - 20.857923076923075
# Total processing time: 7.046875
# (426, 7)
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\create_solution.py:74: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   distances['Dmin'] = distances.min(axis=1)
# (77, 12)
# (148, 16)
# C:\Users\marle\AppData\Local\Temp\ipykernel_12648\1747787820.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_results = df_results.append(dict_results, ignore_index=True)
# 2023-08-10 08:47:58.391 | INFO     | __main__:get_results:6 - From 2022-08-22 to 2022-08-29
# C:\Users\marle\OneDrive - tbs-education\00_Masterarbeit\Code\notebooks\..\src\co2_modells.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["
{'T1': [['T1', 'C1181', 'C694', 'C661', 'C2098...
# 44  {'T1': [['T1', 'C935', 'C284', 'C238', 'C617',...
# 45  {'T1': [['T1', 'C238', 'C1948', 'C617', 'C1017...
# 46  {'T1': [['T1', 'C284', 'C196', 'C55', 'C79', '...
# 47  {'T1': [['T1', 'C353', 'C163', 'C341', 'C124',...
# 48  {'T1': [['T1', 'C1017', 'C2241', 'C425', 'C410...
# 49  {'T1': [['T1', 'C338', 'C68', 'C701', 'C826', ...
# 50  {'T1': [['T1', 'C79', 'C1948', 'C2241', 'C425'...
# 51  {'T1': [['T1', 'C1181', 'C694', 'C661', 'C2098...
#
#     processing time railroad  volume
# 0                   5.984375    10.0
# 1                   7.531250    10.0
# 2                   4.453125    10.0
# 3                   4.812500    10.0
# 4                   4.843750    10.0
# 5                   5.812500    10.0
# 6                   4.765625    10.0
# 7                   4.328125    10.0
# 8                   3.468750    10.0
# 9                   6.312500    10.0
# 10                  5.984375    10.0
# 11                  5.625000    10.0
# 12                  5.234375    10.0
# 13                  6.968750    10.0
# 14                  5.906250    10.0
# 15                  7.218750    10.0
# 16                  5.953125    10.0
# 17                  4.406250    10.0
# 18                  4.625000    10.0
# 19                  5.234375    10.0
# 20                  4.796875    10.0
# 21                  4.796875    10.0
# 22                  4.968750    10.0
# 23                  6.140625    10.0
# 24                  5.062500    10.0
# 25                  4.656250    10.0
# 26                  5.343750    10.0
# 27                  6.906250    10.0
# 28                  6.218750    10.0
# 29                  5.515625    10.0
# 30                  5.343750    10.0
# 31                  6.500000    10.0
# 32                  4.671875    10.0
# 33                  5.671875    10.0
# 34                  5.062500    10.0
# 35                  4.218750    10.0
# 36                  5.437500    10.0
# 37                  5.750000    10.0
# 38                  5.968750    10.0
# 39                  4.937500    10.0
# 40                  5.078125    10.0
# 41                  5.093750    10.0
# 42                  5.046875    10.0
# 43                  6.078125    10.0
# 44                  6.218750    10.0
# 45                  5.390625    10.0
# 46                  6.593750    10.0
# 47                  6.171875    10.0
# 48                  7.796875    10.0
# 49                  7.656250    10.0
# 50                  5.937500    10.0
# 51                  6.375000    10.0

# %%
df_results_total = pd.concat([
    create_table_total(df_results_daily, "daily planning"),
    create_table_total(df_results_bi_daily, "bi-daily planning"),
    create_table_total(df_results_weekly, "weekly planning")], axis = 1)
df_results_total

# %%
df_results_weekly.head(5)[["co2 road", "co2 railroad"]].T

# %%
writer = pd.ExcelWriter('results/results_base.xlsx')
df_results_daily_mean.to_excel(writer,'Daily average')
df_results_total.to_excel(writer,'Total')
writer.save()
writer.close()

# %% [markdown]
# ***

# %% [markdown]
# ## Scenario 3: Combining two DC's

# %% [markdown]
# ### Daily

# %%
from src.evaluation_multi import co2_modell_multi

# %%
df_combined = pd.concat([df_dc1, df_dc2]).head(1000)

# %%
columns = ["date from",
            "date to",
            "co2", 
            "distance", 
            "processing time",
            "df shape"]
df_results_combined = pd.DataFrame(columns = columns)
date_from = "2022-01-03"
date_to = "2022-01-04"
dcs = ["DC1", "DC2"]
dict_results, df_results_details_combined = co2_modell_multi(dcs, df_combined, df_distance_matrix, dict_terminals, date_from, date_to)
# df_results_combined = df_results_combined.append(pd.DataFrame(dict_results, index = ["combined"]))
# for dc in dcs:
#     dict_results, df_results_details = co2_modell_multi([dc], df_combined, df_distance_matrix, dict_terminals, date_from, date_to)
#     df_results_combined = df_results_combined.append(pd.DataFrame(dict_results, index = [f"{dc} only"]))

# %%
df_results_details_combined
