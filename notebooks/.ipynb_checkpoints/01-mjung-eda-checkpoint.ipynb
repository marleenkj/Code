# %%
import pandas as pd

# %%
data_nshift = pd.read_csv('../ui/app/assets/SE _ nShift _ Oct 22.csv', sep='|')
# Out:
# C:\Users\SESA667490\AppData\Local\Temp\ipykernel_27252\1532192268.py:1: DtypeWarning: Columns (16) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_nshift = pd.read_csv('../ui/app/assets/SE _ nShift _ Oct 22.csv', sep='|')

# %%
data_nshift.head()
# Out:
#   Shipper Shipper country code  Shipper zip   Shipper city   Shipper address  \
# 0  Evreux                   FR        27900  Guichainville  Rue Roland Garos
# 1  Evreux                   FR        27900  Guichainville  Rue Roland Garos
# 2  Evreux                   FR        27900  Guichainville  Rue Roland Garos
# 3  Evreux                   FR        27900  Guichainville  Rue Roland Garos
# 4  Evreux                   FR        27900  Guichainville  Rue Roland Garos
#
#   Order number Shipment number                Receiver Receiver country code  \
# 0    879233105     2,50076E+14              AFCA GENAS                    FR
# 1    879227036     2,50076E+14       ELIWELL FRANCE SA                    FR
# 2    879232085     2,50076E+14                    SERT                    FR
# 3    879232252     2,50076E+14                     OET                    FR
# 4    879232023     2,50076E+14  YESSS DECINES CHARPIEU                    FR
#
# ...

# %% [markdown]
# they added the distance and the emission per kg of product and emission on route
# distance per city
